# %% [markdown]
# **Student's T Distribution**
# <br></br>
# It is a small sample size approximation of a normal distribution.
#
# eg: the average lap times for the entire season of a Formula One race follow a normal distribution, but the lap times for the first lap of the Monaco Grand Prix would follow a student's t distribution.
# $$Denoted\;by\; t(k)\;\;where\;k\;is\;degree\;of\;freedom$$
# $$Y \sim t(k)$$
#
# as variable y follows a student's T distribution with 'k' degrees of freedom.
# <br></br>
# **Difference between Student's T Distribution VS Normal Distribution :**
#
# * The curve of the students t distribution is also bell shaped and symmetric.However, it has fatter tales to accommodate the occurrence of values far away from the mean. That is because if such a value features in our limited data, it would be representing a bigger part of the total.
#
# * Another key difference between the students t-distribution and the normal one is that apart from the mean $(\mu)$and variance $(\sigma^2)$, we must also define the degrees of freedom for the distribution $(k)$.
#
# * As long we have degree of freedom k >2
#     * $Expected\;Value\;of\;t-distribution E(Y) = mean\;(\mu)$
#     * $Var(Y) = \frac{S^2*k}{k-2}$ where $S^2$ is Variance of Sample
#
# <br>Overall, the students t distribution is frequently used when conducting statistical analysis. It plays a major role when we want to do hypothesis testing with limited data, since we also have a table summarizing the most important values of its CDF.

# %% [markdown]
# ***

# %% [markdown]
# ### PROBABILITY FREQUENCY DISTRIBUTION
#
# * "Y"$\rightarrow$ The actual outcome of an event.
# * "y"$\rightarrow$ One of the possible outcomes.
#
#
# One way to denote the likelihood of reaching a particular outcome Y is $P(Y=y)$ or $p(y)$
#
# $p(y)$ is called the probability function.
#
# eg: "Y" could represent the number of red marbles we draw out of a bag and "y" would be a specific number like three or five? Then we expressed the probability of getting exactly five red marbles as $P(y = 5)$ or $p(5)$.

# %% [markdown]
# ### Mean, Variance, Standard Deviation
# <br></br>
# * **Mean :** Mean of a distribution is the average value.
#
# $$Mean \rightarrow "\mu"$$
#
# * **Variance :** Variance is essentially how spread out the data is. We measure this spread by how far away from the mean all the values are. The more dispersed the data is, the higher its variance will be.
#
#  $$Variance \rightarrow "\sigma^2"$$
#
# >**Note :** Variance is always measured in unit square. if x is in seconds, $variance\;(\sigma^2)\;is\;"sec^2"$
#
#
# <br></br>
# * **Standard Deviation :** Standard deviation is simply the positive square root of variance.
#
# $$Standard Deviation \rightarrow \sigma$$
#
# standard deviation is measured in the same units as the mean.
#
# #### For sample Data:
# $$Sample\;Mean \rightarrow \bar x $$
#
# $$Sample\;Variance \rightarrow S^2$$
#
# $$Sample\;Standard\;Deviation \rightarrow S$$

# %% [markdown]
# **Relationship between Mean and variance:**
# >$$\sigma^2 = E((Y-\mu)^2)\;\;\; = E(Y^2)-\mu ^2$$
#
# The variance equals the expected value of the squared difference from the mean for any value.

# %% [markdown]
# #### Types of Probability Distribution
# <br></br>
# - **Discrete Distribution:** They have finite number of outcomes. eg: rolling a dice.
# <br></br>
# - **Continuous Distribution:** They have infinetly many outcomes. eg: recording time.

# %% [markdown]
# ### Discrete Distribution:
#
# The probability of an interval for a discrete distribution is done by adding up the possibilities of each individual outcome in the interval occuring.
# <br></br>
# ### Types of Discrete Distribution:
# <br></br>

# %% [markdown]
# #### 1. Uniform Distribution
#
# It is denoted by $U(a,b)$ where a and b are range of values of a dataset.
#
# $$X\sim U(3,7)$$
# we read the following statement as Variable X follows a discrete uniform distribution ranging from 3 to 7.
#
# Since the expected value does not bring any predictive power, we cannot construct an interval around it and be certain it will yield a high probability.
#
# >Events which follow the uniform distribution are ones where all outcomes have equal probability i.e they are "equiprobable". eg: rolling a dice where chance of getting each number is equal.
# So both mean and the variance are uniterpretable and possses not predictive power.
#
# <br></br>

# %% [markdown]
# #### 2. Bernoulli Distribution
#
# Experiment which has two outcomes. eg: tossing a coin. Values always ranges between 0 to 1.
#
# $$It\;is\;denoted\;by\;"Bern" $$ $$X\sim Bern(p)$$
# we read the following statement as Variable X follows a Bernoulli distribution with a probability of success equal to P.
# <br></br>
# Conditions for Bernoulli Distribution:
# - 1 Trial
# - 2 Possible outcomes
# - eg: tossing a coin, marking True or False
# <br></br>
# We often have to assign which outcome is 0 and which outcome is 1.
#
# $$0\leq\;p\;\leq1$$
#
# $$q\;=\;1\;-\;p$$
#
#
# After doing so, we can calculate the expected value i.e $E(X) = p\;or\;E(X) = 1-p$
# <br></br>
# Conventionally, we also assign a value of 1 to the event with the probability equal to P and 0 to 1-p. So, E(X) expresses the likelihood of the favoured Event. Since we only have one trial and a favorite event. We expect that outcome to occur. i.e $E(X) = p$
#
# $$Variance\;of\;bernoulli\;distribution\;is\;always\; = p(1-p)$$
#
# <br></br>

# %% [markdown]
# #### 3. Binomial Distribution
# <br></br>
# - Binomial Distribution is a sequence of identical Bernoulli events.
#
# - It is repeated for fixed number of times.
#
# - The trials are independent and have 2 mutually exclusive outcomes either success or failure.
#
# - The probability of success is same for all trials
# >$$It\;is\;denoted\;by "B"$$ $$B\;(n,p)$$ $$X \sim B\;(10,0.6)$$
# We read the following statement as variable X follows a binomial distribution with 10 trials and a likelihood of 0.6 to succeed on each individual trial i.e it's not biased
#
# Here $n\;\longrightarrow$ is number of trials and $p \longrightarrow$ is success probability for each trials.
# <br></br>
#
# >We can express a Bernoulli distribution as a binomial distribution with a single trial.$$Bern(p)=Bern(1,p)$$
#
#
# **Difference between bernoulli and Binomial Distribution:**
#
#     In a test of 10 questions with only True or False.
#
# - Bernoulli $\rightarrow$ Guessing 1 question
#     - $E(Bernoulli\;event)\rightarrow$ Which outcome we expect for single trial.
#
# - Binomial $\rightarrow$ Guessing all 10 questions
#     - $E(Binomial\;event)\rightarrow$ The number of times we expect to get a specific outcome.
#
# <br></br>
# The graph of the binomial distribution represents the likelihood of attaining our desired outcome a specific number of times. If we run $"n"$ trials, our graph would consist $"n+1"$ mini bars, one for each unique value from zero to N. for instance, we could be flipping the same unfair coin. If we toss it twice, the mini bars will be three different outcomes (0,1,2 tails).
#
# <br></br>
# **The Probability Mass Function(PMF)/Probability distribution function :**
#
# >$$p(y) = {n \choose x}*p^x*(1-p)^{n-x}$$
#  OR
#
# >$$p(y)\;=\;{}^nC_x*p^x*(1-p)^{n-x}$$

# %% [markdown]
# The probability mass function for a binomial distribution is the product of the number of combinations of picking x many elements out of n multiplied p to the power of x multiplied 1-p  to the power of n-x.
#
# <br></br>
# eg: there is a 60% i.e 0.6 chance of general motor share to increase.
# <br></br>
# So to calculate 3 increase in 5 days:
#     $y \rightarrow 3 , $ $n \rightarrow 5 , $ $p \rightarrow 0.6$
#
# $$p(x) = 5^C_3 * 0.6^3 * 0.4^2 \;\; = \;0.3456\;or\;34.56 \% $$
#
# There is 34.56% chance of increase in stock value 3 out of 5 days.

# %% [markdown]
# Ans - x = 15
#
#       n = 18
#
#       p = 85% = 0.85
#
# so $p(x) =^(18)C_15 * 0.85^15 * 0.85^(18-15)$

# %% [markdown]
# **Expected values for Binomial :**
#
# The expected value equals the sum of all values in the sample space multiplied by their respective probabilities
# >$$E(X) = x_0 * p(x_0) + x_1 * p(x_1)+....x_n * p(x_n) $$
# $$Y \sim B\;(n,p)$$
# $$E(Y)= p * n$$
#
# The expected value formula for a binomial event $E(Y)$ equals the probability of success $(p)$ for a given value multiplied by the number of trials we carry out $(n)$, this seems familiar because this is the exact formula we used when computing the expected values for categorical variables.
#
# <br></br>
# <br></br>
#
# **Variance for Binomial :**
#
# >$$\sigma ^2 = n * p * (1-p)$$
# $$i.e.\;\;5 * 0.6 * 0.4 = 1.2$$
#
# **Standard Deviation for Binomial :**
#
# >$$\sigma = {(\sqrt {\sigma^2}) } = {\sqrt {1.2^2}} = 1.1$$
#
# <br></br>
# Knowing the expected value and the standard deviation allows us to make more accurate future forecasts.

# %% [markdown]
# **Q. When do we create a Probability Mass Function(PMF) and when do we create a Probability Density Function(PDF)?**
#
# > Whenever the Values are continous the graph created by it is PDF. Whenever the values are dicrete the graph generated by it is is PMF.

# %%
# Q- In a survey, it was found that 85% of the household have high speed internet. 
#    If you take sample of 18 Households, what is the probability that *exactly* 15 will have high speed internet? 

# Ans- 
binomial_q1 = Image.open('C://Users//Mohit.Kumar//Pictures//DS//binomial_q1.png')
binomial_q1.resize((800,300))
# Out:
# <PIL.Image.Image image mode=RGBA size=800x300 at 0x267EB8E1820>

# %%
# Q- In a survey, it was found that 85% of the household have high speed internet. 
#    If you take sample of 18 Households, what is the probability that *atleast* 15 will have high speed internet? 

# Ans- 
binomial_q2 = Image.open('C://Users//Mohit.Kumar//Pictures//DS//binomial_q2.png')
binomial_q2.resize((600,200))
# Out:
# <PIL.Image.Image image mode=RGBA size=600x200 at 0x267EBBDF940>

# %% [markdown]
# #### 4. Poisson Distribution
# <br></br>
# The Poisson Distribution deals with the frequency with which an event occurs within a specific interval. Instead of the probability of an event, the Poisson Distribution requires knowing how often it occurs for a specific period of time or distance.
# <br></br>
# >$$It\; is \; denoted\; by\;\; Po(\lambda)$$
# $$Y \sim Po(4)$$
#
# We read above statement as variable y follows a poisson distribution with Lambda equal to four.
#
# >$$Formula\;\;P(Y) = \frac{\lambda ^ y * e ^ {-\lambda}}{y!}$$
#
#
# $e \rightarrow Euler's\;number\;(Napier's\;Constant), e\approx 2.72\;\;and\;\; e^{-\lambda}=\frac{1}{e^\lambda}$
#
# <br></br>
# eg:imagine you created an online course on probability, usually your students asked you around four questions per day, but yesterday, they asked seven. Surprised by this sudden spike in interest from your students, you wonder how likely it was that they would ask exactly seven questions
# i.e $P(y=7)=?$
# $$average\;no.\;of\;questions\;here\;is\; \lambda \rightarrow 4$$
# $$time\;interval\;is\;entire\;1\;day$$
# $$the\;singular\;instance\;you\;are\;interested\;in\;is\;y \rightarrow 7$$
# $$So,\; P(7) = \frac{4^7\;*\;e^{-4}}{7!}\;\;\approx 0.06 $$
#
# So there is 6% chance of receiving exactly 7 questions.
#
# <br></br>
# **Expected Value for Poisson Distribution**
#
# $$E(Y) = \lambda$$
#
# **Variance for Poisson Distribution**
# $$\sigma^2 = \lambda$$
#
# $$So \;\; mean\;(\mu) = Variance\;(\sigma^2) = \lambda$$
# <br><br>
#
#     Q. Why does the graph of the Poisson Distribution start from 0 on the X-axis?
#
# Because we are measuring the frequency of occurrence over a given time interval or distance.

# %% [markdown]
# ### Continuous Distribution:
#
# * These have infinetly continuous outcomes.
# * Their Sample space is infinite.
# * We cannot record the frequency of each distinct value.
# * cannot be represented in the form of a table.
#
# **Graph of Probability Density function (PDF) :** $f(y)\ge 0$
#
# the function depicts associate probability for every possible value of "y"
#
# the graphs for continuous distributions slightly resemble the ones for discrete distributions.However, there are more elements in the sample space, so there are more bars on the graph.Furthermore, the more bars, the narrower each one must be. This results in a smooth curve that goes along the top of these bars.
#
# We call this the probability distribution curve, since it shows the likelihood of each outcome. $(PDC)$
#
# The greater the denominator becomes, the closer the fraction is to zero. For reference, one third is closer to zero than a half and a quarter is closer to zero than either of them.
#
# It is accepted that the probability for any individual value from a continuous distribution to be equal to zero.
# $$P(X) = 0$$
# $$P(x>X) = P(x\ge X)$$
#
# eg: the probability of a college student running a mile in under six minutes is the same as them running it for at most six minutes. That is because we consider the likelihood of finishing in exactly six minutes to be zero.
#
# $$P(x<6min) = P(x\le 6min)$$
# $$P(x=6min) = 0$$

# %% [markdown]
# **Cummulative Distribution Function (CDF) F(y):**
# $$Denoted\;by\;F(y)= P(Y\le y)$$
# It is cumulative, this function encompasses everything up to a certain value, we denote the CDF as capital F of y for any continuous random variable Y.As the name suggests, it represents probability of the random variable being lower than or equal to a specific value.
#
# Since no value could be lower than or equal to negative infinity, the CDF value for negative infinity would equals zero. Similarly, since any value would be lower than plus infinity, we would get a one if we plug plus infinity into the distribution function. Discrete distributions also have CDFs, but they're used far less frequently, that is because we can always add up the PDF values associated with the individual probabilities we are interested in.
#
# CDF is especially useful when we want to estimate the probability of some interval.Graphically, the area under the density curve would represent the chance of getting a value within that interval. We find this area by computing the integral of the density curve over the interval from A to B.
# $$\int_a^b p(x)dx$$
#
#
# $$PDF \longrightarrow CDF \int_ {-\infty}^y p(y)dy = F(y)  \leftarrow Integration$$
# <br></br>
# $$CDF \longrightarrow PDF\;\;p(y)=F(y)\frac{d}{dy}  \leftarrow Derivative$$
#
# <br></br>
# **Expected value E(y) :**
# $$E(y) = Integral \int_ {-\infty}^\infty yp(y)dy$$
#
# **Variance Var(y) :**
#
# $$Var(y) = E(y^2) - E(y)^2$$
#
#     **Q. Graphically, what is the relationship between the PDF and the CDF of a continuous distribution?**
# >The CDF represents the area under the curve of the PDF.

# %%
cumulative_distri = Image.open(r'C:\Users\mohit.kumar\Pictures\DS\cumulative_distri.png')
cumulative_distri.resize((400,300))
# Out:
# <PIL.Image.Image image mode=RGBA size=400x300 at 0x22DB3AF0CD0>

# %% [markdown]
# ### Chi-square Distribution
#
# $$Denoted\;by\;\; \chi^2*(k)$$
# $$Y \sim\;\chi^2*(k)$$
#
# we denote chi square distribution as the capital Greek letter K squared, followed by a parameter K depicting the degrees of freedom.
#
# <br></br>
# Chi Squared is most featured in statistical analysis when doing hypothesis testing and computing confidence intervals.In particular, we most commonly find it when determining the **goodness of fit** of categorical values. It is a non parametric test used for **finding realtion between categorical data**.
#
# $$Formula\;for\;Chi-Square\;test\;Statistics:$$
#
# $$\chi^2 = \sum{\frac{(f_o\;-\;f_e)^2}{f_e}}$$
# $where\;f_o\longrightarrow\;frequency\;of\;observed$
#
# $where\;f_e\longrightarrow\;frequency\;of\;expected$
#
# <br></br>
# **Characteristics**
#
# * Just by looking at the graph, you can tell the distribution is not symmetric, but rather **asymmetric**. Its graph is highly skewed to the right.
# <br></br>
# * Furthermore, the values depicted on the x axis start from zero rather than a negative number.This, by the way, shows you yet another transformation.
# <br></br>
# * Elevating the students t-distribution $(Y \sim t(k))$ to the second power gives us the chi squared $(Y^2 \sim\;\chi^2*(k))$ and vice versa, finding the square root of the Chi squared distribution $(X^2 \sim\;\chi^2*(k))$ gives us the students t. $(\sqrt x \sim t(k))$
# <br></br>
# * Convenient feature of the Chi squared distribution is that it also contains a table of known values, just like the normal $N$ or students t distribution's $T$.
# <br></br>
# * $Expected\;Value\;of\;Chi-Square  E(X) = k$ . The expected value for any chi squared distribution is equal to its associated degrees of freedom k.
# * $Var(X) = 2 k$ Its variance is equal to two times the degrees of freedom or simply two times K.

# %%
chi_square_qstn = Image.open(r'C:\Users\mohit.kumar\Pictures\DS\chi_square_question.png')
chi_square_qstn.resize((1000,300))
# Out:
# <PIL.Image.Image image mode=RGBA size=1000x300 at 0x1D476541190>

# %% [markdown]
# - Step 1: Determine $H_o$ and $H_1$
#
#
# - Step 2: Calculate $\alpha$ significance value
#
#
# - Step 3: calculate Degree of Freedom and correspondingly calculate chi-square value from the table.
#
#
# - Step 4: Decision Rule: IF $\chi^2$ is greater than chi square value from the table we reject the null hypothesis.
#
#
# - Step 5: Calculate chi-square test statistics

# %% [markdown]
# Ans-
#
# Step 1 - $H_o\longrightarrow\;$The data meets the Age Distribution and $H_1\longrightarrow\;$ Distribution of Ages has changed.
#
# Step 2 - $\alpha = 0.05$
#
# Step 3 - Degree of freedom here is (3 categories - 1) = 2
#
# So, value from table wth d.f. = 2 and $\alpha$ = 0.05 $\;\;So\;chi-square\;score\;\longrightarrow\;5.99$
#
# Step 5 - Chi-squared test statistics $\chi^2$ =  232.94
#
# which is greater than 5.99 $\chi^2\;>\;5.99\;\;$ **we reject the null hypothesis. So Distribution of Age has got changed**
#
# NOTE: $f_1(2000)$ is calculated on basisi of $f_0(2010)$

# %%
step4_chi_square = Image.open(r'C:\Users\mohit.kumar\Pictures\DS\step_4_chi_square.png')
step4_chi_square
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1215x629 at 0x1D476FE65E0>

# %%
# Question 2 for row and columnwise data

Q2 = Image.open(r'C:\Users\mohit.kumar\Pictures\DS\q2.png')
Q2.resize((800,400))
# Out:
# <PIL.Image.Image image mode=RGBA size=800x400 at 0x1D47639F610>

# %%
q_2_1 = Image.open(r'C:\Users\mohit.kumar\Pictures\DS\q_2_1.png')
q_2_1.resize((800,300))

# Step-1 Null hypo : Colour and Gender are not related
#        Alternate Hypo : Colour and Gender are related

# Step 3 is very important to calculate degree of freedom for data with rows and columns
# Out:
# <PIL.Image.Image image mode=RGBA size=800x300 at 0x1D476664940>

# %%
# step 5 calculating X^2 chi-square statistics value

q_2_2 = Image.open(r'C:\Users\mohit.kumar\Pictures\DS\q_2_2.png')
q_2_2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1684x622 at 0x1D476FE6670>

# %%
chi_square_table = Image.open(r'C:\Users\mohit.kumar\Pictures\DS\chi_square_table.png')
chi_square_table.resize((900,600))
# Out:
# <PIL.Image.Image image mode=RGBA size=900x600 at 0x1D476FE6B20>

# %% [markdown]
# #### Exponential Distribution
# $$Denoted\;by\; Exp(\lambda)$$
# $$X \sim Exp (\frac{1}{2})$$
# *variable X follows an exponential distribution lambda.*
#
# <br></br>
# Variables which most closely follow an exponential distribution are ones with a probability that initially decreases before eventually plateauing.
#
# Eg: One such example is the number of views for a YouTube Vlog.There is a great interest upon release, so it starts off with many views in the first day or two. After most subscribers have had the chance to see the video, the view counter slows down. Even though the aggregate amount of views keeps increasing, the number of new ones diminishes daily. As time goes on, the video either becomes outdated or the author produces new content, so viewership focus shifts away.
#
# Therefore, it is more likely for a random viewing to have occurred close to the video's initial release
#
# <br></br>
# Graphically, the **PDF** of such a function would start off very high and sharply decrease within the first few time frames, the curve somewhat resembles a boomerang with each handle lining up with the X and Y axis.
#
#
# In a weird way, the **CDF** would also resemble a boomerang. However, this one has shifted 90 degrees to the right. As you know, the cumulative distribution eventually approaches one, so that would be the value where it plateau.
#
# <br></br>
#
# To define an exponential distribution, we require a rate parameter denoted by  lambda $(\lambda)$. This parameter determines how fast the CDV curve reaches the point of plateauing and how spread out the graph is.
#
# * $Expected\;Value\;of\;Exponential\;Distribution\;is\;\; E(Y) = \frac{1}{\lambda}$ .
# * $Var(Y) = \frac{1}{\lambda^2}$.
#
#
# However, unlike the normal $(N)$ or Chi-squared distributions $(\chi^2)$, we do not have a table of known variables for it.
# That is why sometimes we prefer to transform it.
#
# Generally, we can take the natural logarithm of every set of an exponential distribution  and get a normal distribution in statistics, we can use this new transform data to run linear regressions. This is one of the most common transformations I've had to perform.
#
# $$Y \sim\;Exp(\lambda),\;\;\; X = ln(y) \;\;\Rightarrow X \sim N (\mu, \sigma^2)$$
#
#         graphs of the Exponential Distribution?
#         The CDF plateaus near 1 mark and the PDF plateaus around the 0 mark.

# %% [markdown]
# #### Logistic Distribution
#
# $$Denoted\;by\;\;Logistic(\mu, S)$$
# $$where\;S\;is\;Scale\;Parameter\;and\;\mu\;is\;Location$$
#
# $$Y\;\sim \;\;Logistic(6, 3)$$
# we read the statement below as variable y follows a logistic distribution with location six and a scale of three.
#
# We often encounter logistic distributions when trying to determine how continuous variable inputs can affect the probability of a binary outcome. This approach is commonly found in forecasting competitive sports events where there exist only two clear outcomes victory or defeat.
#
# eg: For instance, we can analyze whether the average speed of a tennis player serve plays a crucial role in the outcome of the match. Expectation dictates that sending the ball with higher velocity leaves opponents with a shorter period to respond. This usually results in a better hit, which could lead to a point for the server.
# To reach the highest speeds, tennis players often give up some control over the shot, so our less accurate.
#
# Therefore, we cannot assume that there is a linear relationship between point conversion and serves beats.
# Theory suggests there exists some optimal speed which enables the serve to still be accurate enough. Then most of the shots we convert into points will likely have similar velocities.
#
# As tennis players go further away from the optimal speed, their shots either become too slow and easy to handle or to an accurate. This suggests that the graph of the **PDF** of the logistic distribution would look similarly to the **normal distribution.**
#
#
# Actually, the graph of the logistic distribution is defined by two key features, its mean$(\mu)$ and its scale parameter$(S)$. The former $(\mu)$ dictator at the center of the graph, whilst the latter $(S)$ shows how spread out the graph is going to be.
#
# Going back to the tennis example, the mean would represent the optimal speed whilst the scale would dictate how lenient we can be with the hit.To elaborate, some tennis players can hit a great serve further away from the optimal speed than others. For instance, Serena Williams can hit fantastic serves even if the ball moves faster or slower than
# it optimally should. Therefore, she is going to have a more spread out PDF than some of her opponents.
#
# <br></br>
# Now let's discuss the **cumulative distribution function (CDF).**
#
# It should be a curve that starts off slow, then picks up rather quickly before plateauing around the one mark.
# That is because once we reach values near the mean, the probability of converting the point drastically goes up.
# Once again, the scale would dictate the shape of the graph. In this case, the smaller the scale, the later the graft starts to pick up, but the quicker it reaches values close to one.
# - It follows an S-shape and plateaus around the value 1.
# - The probability drastically starts to increase once we reach values close to mean
# - The steeper the curve, the faster it reaches value close to absolute certainity (1).
#
# <br></br>
# * $ Expected\;Value\;of\;Logistic\;Distribution\;is\;\; E(Y) = \mu$
# * $Var(Y) = \frac{S^2 * \pi^2}{3} \;\;where\; S^2\;is\;square\;of\;scale$

# %% [markdown]
# Q- When to use pmf or pdf?
# > Ans - pmf is used for discrete values and for continuous values pdf is used.

# %% [markdown]
# ### Chebyshev's Inequality
#
# **Imperical Formula**
#
# $If\;X\approx\;Gaussian\;Distribution$
#
# $Probability\;(\mu\;-\;\sigma\;\leqslant\;\chi\;\leqslant\mu\;+\;\sigma)\;\;\longrightarrow\;68\%$
#
# $Probability\;(\mu\;-\;2\sigma\;\leqslant\;\chi\;\leqslant\mu\;+\;2\sigma)\;\;\longrightarrow\;95\%$
#
# $Probability\;(mu\;-\;3\sigma\;\leqslant\;\chi\;\leqslant\mu\;+\;3\sigma)\;\;\longrightarrow\;99.7\%$
# <br></br>
#
# - $But\;If\;Y \neq Gaussian\;Distribution$
#
# $$Probability\;(\mu\;-\;k\sigma\;\leqslant\;y\;\leqslant\mu\;+\;k\sigma)\;\geqslant\;(1-\frac{1}{K^2})$$
#
# $where\;"k"\;may\;be\;standard\;deviation\;and\;value\;of\;k\;\geq\;2$
# <br></br>
#
# - so for 2 standard deviation i.e. k = 2 in Chebyshev equation:
#
# $$Probability\;(\mu\;-\;2\sigma\;\leqslant\;y\;\leqslant\mu\;+\;2\sigma)\;\geqslant\;(1-\frac{1}{K^2})\longrightarrow(1-\frac{1}{4})\longrightarrow(\frac{3}{4})\longrightarrow\;75\%$$
#
# - so for 3 standard deviation i.e. k = 3 in Chebyshev equation:
#
# $$Probability\;(\mu\;-\;3\sigma\;\leqslant\;y\;\leqslant\mu\;+\;3\sigma)\;\geqslant\;(1-\frac{1}{K^2})\longrightarrow(1-\frac{1}{9})\longrightarrow(\frac{8}{9})\longrightarrow\;88.9\%$$
#
#
# - so for 4th standard deviation i.e. k = 4 in Chebyshev equation:
#
# $$Probability\;(\mu\;-\;4\sigma\;\leqslant\;y\;\leqslant\mu\;+\;4\sigma)\;\geqslant\;(1-\frac{1}{K^2})\longrightarrow(1-\frac{1}{16})\longrightarrow(\frac{15}{16})\longrightarrow\;93.75\%$$
#
# **NOTE: There is no 1st Standard Deviation for Y not belonging to gaussian distribution**

# %% [markdown]
# ### Power Law (80 - 20 rule):
#
# - 80% of 'y' will be satisfied by 20% of 'x' and 80% of 'x' will be satisfied by 20% of 'y'
#     - eg: 80% of wealth is accumulated by 20% of people
#
# - It follows Pareto Distribution

# %%
power_rule = Image.open('C://Users//Mohit.Kumar//Pictures//DS//power_rule.png')
power_rule.resize((600,350))
# Out:
# <PIL.Image.Image image mode=RGBA size=600x350 at 0x22898448B80>

# %% [markdown]
# #### NOTE:
#
# - **Log Normal distribution is converted into Gaussian Distribution through LOG TRANSFORMATION $(log_e(x))$ known as TRANSFORMATION**
#
#
# - **Pareto Distribution is converted into Gaussian Distribution using BOX COX TRANSFORM**

# %% [markdown]
# ***

# %% [markdown]
# ### Pareto Distrubtion
#
# Pareto is transformed into Normal Distribution bcoz most algorithms assume data to be gaussian distributed and make good assumptions on it.

# %% [markdown]
# **Pareto is converted into Gaussian through following ways:**
#
# Pareto Distribution $x\;\;=\;\;{x_1,\;x_2,\;x_3,\;x_4......x_n}$
#
# $\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\Downarrow$
#
# Gaussian Distribution $y\;\;=\;\;{y_1,\;y_2,\;y_3,\;y_4......y_n}$
#
# 1. Apply a BoxCox function which will take all the x values. This will create a value $\alpha$ (Height of the Pareto graph)
#
#
# 2. Based on $\alpha\;value$, 'y' will be calculated
#
#     - $y_i\;=\;\frac{(x_i)^\alpha\;-\;1}{\alpha}\;\;\;\;\; if\;\alpha\neq0\;\Longrightarrow\;BoxCox\;Transform$
#     <br></br>
#     - $y_i\;=\;log_e(x)\;\;\;\; if\;\alpha\;=\;0\;\Longrightarrow\;LOG\;Normal\;Distribution$

# %%
Pareto_typ1 = Image.open(r'C:\Users\mohit.kumar\Pictures\DS\Pareto_type1.png')
Pareto_typ1.resize((500,300))
# Out:
# <PIL.Image.Image image mode=RGBA size=500x300 at 0x1D46CED9B50>

# %%
## We will check whether a distribution is gaussian distributed or not
## QQ Plot (Qunatile Quantile Plot)

import numpy as np
import statsmodels.api as sm
import pylab as py

# %%
# Random data points generated
# Standard normal distribution of 100 data points with mean is 0 and Standard deviation is 1

data_points = np.random.normal(0,1,100)
data_points
# Out:
# array([ 3.83607174e-01, -1.47967918e+00, -5.18239039e-01,  8.31927210e-01,
#         1.92421151e+00,  1.51025127e-01,  1.08795882e-01,  5.48995592e-01,
#         1.13606090e+00, -4.40406769e-01,  7.29357106e-01,  9.12772034e-01,
#         1.91840461e+00, -7.69093366e-01,  1.09915184e+00, -6.80652652e-01,
#         5.01843039e-01, -7.29504570e-01, -3.79560285e-01, -1.25360253e+00,
#        -1.33616354e+00, -7.83652130e-01, -2.36101851e+00,  1.40356558e+00,
#        -8.75208529e-01, -2.24015236e+00,  2.03217607e-01,  4.71764123e-01,
#         1.13658361e+00,  8.66625311e-01,  1.90060140e-01, -1.67764293e+00,
#         1.51275892e+00, -3.15851292e-01, -4.06675933e-01,  5.24678822e-01,
#         6.25634037e-01,  3.65855060e-01, -9.11048190e-01,  3.83569438e-02,
#         7.57025599e-01, -1.13330166e+00, -1.50069415e-01, -2.47887891e-01,
#         4.58645446e-01, -7.60091567e-01,  5.16741223e-01,  1.24391138e+00,
# ...

# %%
# applying qqplot on the data with thickness of line = 45
sm.qqplot(data_points, line = '45')
py.show()
# Out:
# C:\Users\mohit.kumar\Anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %% [markdown]
# if all blue dots lie on the red line, then it will follow gaussian distribution

# %%
import seaborn as sns
sns.displot(data_points)

# %%
# creating pdf on top of the bargraph

sns.displot(data_points, kind='kde')

# %%
# using log normal distribution with mean as 0 and S.D as 1
gfg = np.random.lognormal(0, 1, 100)

print(gfg)
# Out:
# [ 0.4457125   0.22924041  1.14909012  0.4349443   2.97509149  0.30270932
#   1.46898984  1.28813774  1.83295805  0.522518    5.30814278  0.79979649
#   0.39049492  1.65674587  0.95580999  0.87051761  1.51412438  1.10793929
#   3.15050549  0.5910464   0.59193818  0.68013722  1.0416075   0.57559613
#   0.31844598  0.99888458  0.29299526  0.55322529  0.45056698  4.56958525
#   0.7265687   0.77111949  2.64832173  1.01218378  1.00273031  0.41100076
#   0.72664238  0.78867795  0.37908201  3.07165312  3.01685966  0.5184903
#   0.43796214  0.40362001  1.87438305  3.37593277  1.01474942  2.49676732
#   1.38882663  1.48466807  0.84354416  0.65545541  0.36258826  0.38887533
#   0.419383    2.26433271  2.74687805  0.41335201  0.34376518  1.86071581
#   2.55985307  0.27221016  0.32682265  1.53510938  2.82831655  1.53155645
#   3.95336376  4.02896445  4.21100558  0.84460266  1.70890268  0.77842594
#   2.68484201  0.22447848  3.55457818  2.52102093  1.06897863  0.36946524
# ...

# %%
sm.qqplot(gfg, line = '45')
py.show()
# Out:
# C:\Users\mohit.kumar\Anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
sns.displot(gfg)

# %%
sns.displot(gfg, kind='kde')

# %%
# Applying log to convert it into gaussian distribution

np.log(gfg)
# Out:
# array([-8.08081163e-01, -1.47298399e+00,  1.38970427e-01, -8.32537298e-01,
#         1.09027479e+00, -1.19498226e+00,  3.84574982e-01,  2.53197563e-01,
#         6.05931083e-01, -6.49095846e-01,  1.66924202e+00, -2.23397970e-01,
#        -9.40340316e-01,  5.04855360e-01, -4.51961454e-02, -1.38667288e-01,
#         4.14837308e-01,  1.02501790e-01,  1.14756291e+00, -5.25860756e-01,
#        -5.24353070e-01, -3.85460709e-01,  4.07651954e-02, -5.52349027e-01,
#        -1.14430242e+00, -1.11604347e-03, -1.22759884e+00, -5.91989967e-01,
#        -7.97248536e-01,  1.51942245e+00, -3.19422241e-01, -2.59911932e-01,
#         9.73926130e-01,  1.21101507e-02,  2.72658459e-03, -8.89160225e-01,
#        -3.19320834e-01, -2.37397210e-01, -9.70002708e-01,  1.12221589e+00,
#         1.10421644e+00, -6.56833954e-01, -8.25622802e-01, -9.07281413e-01,
#         6.28279567e-01,  1.21667166e+00,  1.46417069e-02,  9.14996823e-01,
# ...

# %%
sm.qqplot(np.log(gfg), line = '45')
py.show()
# Out:
# C:\Users\mohit.kumar\Anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
sns.displot(np.log(gfg))

# %%
# now after applying log to the values it follows normal distribution
sns.displot(np.log(gfg), kind='kde')

# %% [markdown]
# ***

# %%
# code to show BOX-COX Transformation of non-normal data

import numpy as np
from scipy import stats

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# generate non-normal data (exponential)
# exponential function is used to create Pareto distribution

original_data = np.random.exponential(size = 1000)

# transform training data and save lambda(alpha) value which will determines the height
# Passing the Pareto distribution to the boxcox transformation for the transformation

fitted_data, fitted_lambda = stats.boxcox(original_data)

# creating axes to draw plots
fig, ax = plt.subplots(1, 2)

# plotting the original data (non-normal)
sns.distplot(original_data, hist = False, kde = True,
            kde_kws = {'shade':True, 'linewidth':2},
            label = "Non-Normal", color = "green",ax = ax[0])

# plotting the fitted date (normal)
# fitted data is after performing boxcox transform over original exponential data
sns.distplot(fitted_data, hist = False, kde = True,
            kde_kws = {'shade':True, 'linewidth':2},
            label = "Normal", color = "green",ax = ax[1])

# adding legends to the subplots
plt.legend(loc = "upper right")

# rescaling the subplots
fig.set_figheight(5)
fig.set_figheight(10)

print(f"Lambda value used for Transformation: {fitted_lambda}")
# Out:
# C:\Users\mohit.kumar\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\mohit.kumar\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Lambda value used for Transformation: 0.2554844750507198

# %%
sm.qqplot(fitted_data, line = '45')
py.show()
# Out:
# C:\Users\mohit.kumar\Anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %% [markdown]
# It is not Gaussian Distributed

# %%
# applyig log to the original data

sm.qqplot(np.log(original_data), line ='45')
py.show()
# Out:
# C:\Users\mohit.kumar\Anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import pylab
x_m = 10
alpha = 15
size = 1000 # size of the sample (no. of random samples)
samples = (np.random.pareto(alpha, size) + 1) * x_m # pareto samples
stats.probplot(samples, dist = 'pareto', sparams = (15, 10), plot=pylab)
plt.show()

# %% [markdown]
# ### converting Pareto into Gaussian by qqplot

# %%
# plotting pareto graph using the same samples

samples = (np.random.pareto(alpha, size) +1 )

# %%
import seaborn as sns
sns.displot(samples, kind = "kde")

# %%
# adding some noise *x_m for better graph representation
samples = (np.random.pareto(alpha, size) +1 )*x_m
sns.displot(samples, kind = "kde")

# %%
# forming pareto graph with sample data
stats.probplot(samples, dist = 'pareto', sparams = (15, 10), plot=pylab)
plt.show()

# %%
# forming normal distribution with sample data

samples  = np.random.normal(0, 1, 100)
stats.probplot(samples, dist = 'norm', sparams = (15, 10), plot=pylab)
plt.show()

# %% [markdown]
# sample is following normal distrbution

# %% [markdown]
# ***

# %% [markdown]
# ## Anova Test(F-Test)
# The t-test works well when dealing with two groups, but sometimes we want to compare more than two groups at the same time.
#
#
# For example, if we wanted to test whether petal_width age differs based on some categorical variable like species, we have to compare the means of each level or group the variable

# %% [markdown]
# ### One Way F-test(Anova) :-
# It tell whether two or more groups are similar or not based on their mean similarity and f-score.
#
# Example : there are 3 different category of iris flowers and their petal width and need to check whether all 3 group are similar or not

# %% [markdown]
# #### Question:

# %%
annova_qstn = Image.open(r'C:\Users\mohit.kumar\Pictures\DS\annova_qstn.png')
annova_qstn.resize((800,400))
# Out:
# <PIL.Image.Image image mode=RGBA size=800x400 at 0x25A51C1A9A0>

# %% [markdown]
# #### Solution:
#
# #### Step 1: Compute Null and Alternate Hypothesis.
#
# #### Step 2: Calculate Degree of freedom

# %%
annova_step2 = Image.open(r'C:\Users\mohit.kumar\Pictures\DS\annova_step2.png')
annova_step2.resize((1000,400))
# Out:
# <PIL.Image.Image image mode=RGBA size=1000x400 at 0x25A51C78370>

# %% [markdown]
# $\alpha$ is the number of categories
#
# N is the total number of values in the table i.e 21
#
#
# There are 3 degree of freedom respective to all categories.

# %% [markdown]
# *find f-table here:*  http://www.socr.ucla.edu/Applets.dir/F_Table.html

# %% [markdown]
# **Step 4: Decision rule will be between df_between and df_within**
#
# - df_between is numerator and df_within is denominator
#
# - so from f-table, critical value = 3.5546 for df_between = 2 and df_within = 18 with $\alpha = 0.05$
#
# - critical value =  3.55

# %% [markdown]
# **Step 5 : calculate F-test (https://www.youtube.com/watch?v=-yQb_ZJnFXw)**

# %% [markdown]
# - **Sum of Squares within groups ( SSW )** is the sum of variance across each seperate columns
#     - calculate mean of each columns seperately
#
#                             0mg	50mg	100mg
#
#         mean of each column	8.142857143	6.714285714	3
#
#
#     - mean of each columns - each values
#     - square of (mean of each columns - each values)
#     - sum of these values
#     - sum of square within group = **10.28571429**
#
#
# - **Sum of Squares between groups** is the sum of variance beteen each groups
#     - mean of each column - mean of total values from SST
#     - (mean of each column - mean of total values from SST ) ^ 2
#     - sum all values
#     - sum of all values * (number of rows)
#     - 14.0952381 * 7 = **98.66666667**
#
#
# - **Total sum of Squares ( SST ) = Sum of squares between groups + Sum of Squares within groups**
#     - **Calculating Total Sum of Squares ( SST )**
#         - put all values together and calculate the mean,  then individual value - mean
#         - now, calculate (individual - mean)^2 and calculate total
#         - This total is SST = 108.952381
#
# $$Total\;sum\;of\;Squares\;( SST )\;\;=\;\;Sum\;of\;squares\;within\;groups\;\;+\;\;Sum\;of\;Squares\;between\;groups$$
#
#
#
# - **Final calculation**
#
#         - Sum of squares between groups
#
# $$\frac{Sum\;of\;Squares\;between\;Groups}{degree\;of\;freedom}\Longrightarrow\;\frac{98.66}{2}\Longrightarrow\;49.33$$
#
#                 - where degree of freedom = number of columns - 1 = 3-1 = 2
#
#         - Sum of squares between groups
#
# $$\frac{Sum\;of\;Squares\;within\;Groups}{degree\;of\;freedom}\Longrightarrow\;\frac{10.28}{18}\Longrightarrow\;0.571$$
#
#                 - where degree of freedom = number of values in the table - number of columns = 21 - 3 = 18
#
# $$F =  \frac{49.33}{0.571}\Longrightarrow 86.39$$

# %% [markdown]
# #### Step : 6
# $$F(86.39)\;>\;critical\;value(3.55)$$
# $$We\;reject\;null\;hypothesis$$

# %% [markdown]
# ***

# %%
from PIL import Image

# %% [markdown]
# ## HYPOTHESIS TESTING
#
# <br></br>
# - **A hypothesis is "an idea that can be tested"**
# - It is a supposition or proposed explanation made on the basis of limited evidence as a starting point for further investigation.
# <br></br>
# $Null\;Hypothesis\;(H_0)$
# - The null hypothesis is the hypothesis to be tested.
# - It is the status quo Everything which was believed until now that we are contesting with our test
# - The concept of the null is similar to innocent until proven guilty We assume innocence until we have enough evidence
# to prove that a suspect is guilty.
# - Conventionally, the equality sign is always included in the null.
#
# <br></br>
# $Alternative\;Hypothesis\;(H_1\;or\;H_A)$
# - The alternative hypothesis is the change or innovation that is contesting the status quo.
# - Usually the alternative is our own opinion The idea is the following:
#     - If the null is the status quo (i e what is generally believed), then the act of performing a test, shows we have doubts about the truthfulness of the null More often than not the researcher’s opinion is contained in the alternative hypothesis.
#
# <br></br>
# **In statistics, the null hypothesis is the statement we are trying to reject. Therefore, the null hypothesis is the present state of affairs, while the alternative is our personal opinion.**
#
# eg:
#
# 1. So, for the data scientist salary example, the null would be the mean data scientist salary is $\$ 113,000$ Then we will try to reject the null with a statistical test So, usually, your personal opinion (e g data scientists don't earn exactly that much) is the alternative hypothesis.
# 2. Our friend Paul told us that the mean salary is > $\$ 125,000$ (status quo, null) Our opinion is that he may be wrong, so we are testing that Therefore, the alternative is the mean data scientist salary is lower or equal to $\$125,000$

# %% [markdown]
# > Q. You want to check if your height is above average, compared to your classmates. State the null and alternative hypotheses of this test.
#
#         H_0: My height is lower or equal to the average height in the class.
#         H_1: My height is higer than the average height in the class.
#
# The null is the status quo (you are 'shorter'), while the alternative is the 'change or innovation' (you are looking for this answer).
#
# Therefore, the null hypothesis of the test is ‘lower or equal’. You have to include ‘equal’ in the null hypothesis, as conventionally, the equality sign is always included in the null.

# %%
signi = Image.open('C://Users//Mohit.Kumar//Pictures//DS//signi.png')
signi.resize((500,200))
# Out:
# <PIL.Image.Image image mode=RGBA size=500x200 at 0x269E09D5160>

# %% [markdown]
# #### Significance Level:
# $$Denoted\;by\; "\alpha"$$
#
# It is the probability of rejecting the null hypothesis if it is true, so the probability of making this error.
#
# Typical values for $\alpha$ are 0.05, 0.01, 0.1
#
# ### Z-TEST
# $$Standardization\;formula$$
# $$Z-test:\;Z = \frac{\bar \chi - \mu_0}{\frac{s}{\sqrt n}}$$
#
# $$where\;"\bar\chi"\;is\;sample\;mean,\;\;\; "\mu_0"\;is\;hypothesized\;mean$$
#
# $$\frac{s}{\sqrt n}\; is\;Standard\;Error$$
#
# We are standardizing or scaling the sample mean we got. If the sample mean is close enough to the hypothesized mean, then Z-test will be close to zero. Otherwise, it will be far away from it.
#
# Naturally, if the sample mean is exactly equal to the hypothesis mean, $\rightarrow\bar\chi = \mu_0\;\;$ Z will be zero $\rightarrow Z=0$. *In all these cases, we would accept the null hypothesis.*
#
# >When we calculate Z, we will get a value, if this value falls into the middle part, then we cannot reject the null. If the Z-value falls outside in the shaded region, then we reject the null hypothesis.That is why the shaded part is called rejection region. The area that is cut off actually depends on the significance level.
# so if level of significance $\alpha\;=\;0.05$ then $\frac{\alpha}{2}\;=\;0.025$ so according to z-table $z = 1.96$
#
# >so +1.96 on the right side and -1.96 on the left side. If the value we get Z from the test is lower than -1.96  or higher than 1.96, we will reject the null hypothesis. Otherwise we will accept it.

# %% [markdown]
# >**NOTE :**
# <br></br>
# Level of Significance $\longrightarrow "\alpha"$
# <br></br>
# Level of Confidence $\longrightarrow "1-\alpha"$
# <br></br>
# Both are opposite to each other i.e. $(\alpha)\;+\;(1-\alpha)\;=\;1$
#
# >**NOTE**
# <br></br>
# Level of significance $\longrightarrow$ For one tailed test we take '$\alpha$' but
# Level of significance $\longrightarrow$ For two-tailed test we consider '$\frac{\alpha}{2}$'

# %%
# How to calculate the rejection-region through alpha
significance_level = Image.open('C://Users//Mohit.Kumar//Pictures//DS//significance_level.png')
significance_level.resize((1200,300))
# Out:
# <PIL.Image.Image image mode=RGBA size=1200x300 at 0x269E09D58E0>

# %% [markdown]
# **How does Hypothesis Testing Work for 2 sided \ 2-tailed test?**
#
# - Calculate a statistic $\rightarrow eg: \bar\chi$
# <br></br>
# - Scale it or standardize it $\rightarrow eg: Z = \frac{\bar \chi - \mu}{\frac{s}{\sqrt n}}$
# <br></br>
# - Check if Z is in the rejection region

# %%
#### Z-test(one Sample)
one_tail_ztest = Image.open('C://Users//Mohit.Kumar//Pictures//DS//one_tail_ztest.png')
one_tail_ztest.resize((1200,500))

# here we are using z-score not z-test
# Out:
# <PIL.Image.Image image mode=RGBA size=1200x500 at 0x24A685B4160>

# %% [markdown]
# ### One Sample Z-test for Proportion
#
# $$Z_o = \frac{\hat P\;-\;P_o}{\sqrt\frac{P\;(1-P_o)}{n}}$$
#
# $where\;\hat P\;is\;the\;proportion,\;P_o\;is\;the\;sample\;mean$

# %% [markdown]
# **Question**
#
# A survey claims that 9 out of 10 doctors recommend Aspirin for their patience with headache. To test the claim, a random sample of 100 doctors is obtained. Out of these 100 doctors, 82 doctors indicate that they recommend Aspirin. Is the claim accurate? $\alpha = 0.05$

# %%
# solution

ztest_proportion = Image.open('C://Users//Mohit.Kumar//Pictures//DS//ztest_proportion.png')
ztest_proportion.resize((1200,400))
# Out:
# <PIL.Image.Image image mode=RGBA size=1200x400 at 0x24A6C603AC0>

# %%
hypothesis = Image.open('C://Users//Mohit.Kumar//Pictures//DS//hypothesis.png')
hypothesis.resize((1200,500))
# Out:
# <PIL.Image.Image image mode=RGBA size=1200x500 at 0x269E09D5CA0>

# %% [markdown]
# #### T-test when population variance is unknown
#
# Confidence Interval with variance unknown and a small sample, the correct statistic to use is the $t-statistics$
#
#  $$T = \frac{\bar \chi - \mu_0}{\frac{s}{\sqrt n}}$$
#      $$where\;\frac{s}{\sqrt n}\; is\; Standard\;error$$
# >**Decision Rule :**
# <br></br>
#     - *Accept if* : The absolute value of the T-score < critical value t
#     <br></br>
#     - *Reject if* : The absolute value of the T-score > critical value t
#
# $$if\;T\;(Standardized\;value)\;>\; t\;(critical\;value\;from\;t-test)\longrightarrow we\;reject\;the\;Null\;Hypothesis$$

# %%
onesample_ttest1 = Image.open(r"C:\Users\mohit.kumar\Pictures\DS\onesample_ttest1.png")
onesample_ttest1.resize((1000,600))
# Out:
# <PIL.Image.Image image mode=RGBA size=1000x600 at 0x24A6C5E8F40>

# %%
onesample_ttest = Image.open(r"C:\Users\mohit.kumar\Pictures\DS\ttest_onesample_ans.png")
onesample_ttest.resize((800,300))
# Out:
# <PIL.Image.Image image mode=RGBA size=800x300 at 0x24A6C6036A0>

# %% [markdown]
# ### p-value
# <br></br>
# - p-value is the smallest level of significance at which we can still reject the null hypothesis, given the observed sample statistics.
# <br></br>
# - When we are testing a hypothesis, we always strive for those *'three zeros after the dot'* This indicates that we reject the null at all significance levels.
# <br></br>
# - 0.05 is often the *cut off line*. If our p-value is higher than 0.05 we would normally accept the null hypothesis (equivalent to testing at 5% significance level). **If the p-value (significance-value) is lower than or equal to 0.05, we would reject the null.**
#
# <br></br>
# **Rule:**
# We should reject the null hypothesis, if:
# $$p-value\;<\;\alpha\;(significance\;level)$$
#
# - test at 90% : 0.00001 < 0.1 $\rightarrow$ REJECT THE NULL HYPOTHESIS
# - test at 95% : 0.00001 < 0.05 $\rightarrow$ REJECT THE NULL HYPOTHESIS
# - test at 99% : 0.00001 < 0.01 $\rightarrow$ REJECT THE NULL HYPOTHESIS
#
# >P-value for one-sided test:$\longrightarrow\;$
#         $(1\;-\;number\;from\;the\;table)$
#
# >P-value for two-sided test:$\longrightarrow\;$
#          $(1\;-\;number\;from\;the\;table)\;X\;2$
#
# <br></br>

# %% [markdown]
#     NOTE:
#
# $z-statistics$
# - Big Samples
# - Known Variances/Unknown Variances
#
# $t-statistics$
# - Small Samples
# - Unknown variances
# <br></br>
#
# **Rule of thumb :**
#
# - Reject the null hypothesis when T-score is bigger than 2
# - P-value is only significant if it is 0.000 something. A p-value higher than 0.05 (> 0.05) is not statistically significant and indicates strong evidence for the null hypothesis. This means we retain the null hypothesis and reject the alternative hypothesis. You should note that you cannot accept the null hypothesis, we can only reject the null or fail to reject it.

# %% [markdown]
# >**NOTE:** Some z- tables don't include negative values, you should be aware that the two statements.
# As the standard normal distribution is symmetrical around 0, the two statements are equal. ie.
# $$-4.67<\;a\;negative\;critical\;value\;z\;\;= \;\;4.67 > a\;positive\;critical\;value\;z$$
#
# <br></br>
# >**Decision rule :**
# Reject if :
#     absolute value of Z-score > positive critical value(z) i.e
#
#  $$if\;Z\;(Standardized\;value)\;>\; z\;(critical\;value\;from\;z-test)\longrightarrow we\;reject\;the\;Null\;Hypothesis$$

# %% [markdown]
# **NOTE: There is a difference between Z-score and Z-test.**
#
# **Z-score is used for population with population mean, sd etc. Z-test is for sample parameter. That's why Z-test has $\sqrt{n}$**

# %%
#pd.read_excel(r'C:\Users\mohit.kumar\Pictures\DS\z_table.xls')

# %% [markdown]
# ***

# %% [markdown]
# #### Statistical errors (Type I Error and Type II Error)
#
# There are two types of errors we can make while testing:
# 1. **Type I error (False positive)**
#     - *wrongly invited her*
#     - When you reject a true null hypothesis.
#     - The probability of making this error is $\alpha$, the level of significance.
#     - Since you, the researcher, choose the Alpha, the responsibility for making this error lies solely on you.
# <br></br>
# 2. **Type II Error (False negative)**
#     - *missed your chance*
#     - when you accept a false null hypothesis.
#     - The probability of making this error is $\beta$.
#     - $\beta$ depends on sample size $(n)$ and variance $(\sigma)$
#     - So if your topic is difficult to test due to hard sampling or the effect you are looking for is almost negligible, it is more likely to make this type of error.
#     - **Power of the test:** Probability of Rejecting a null hypothes is False. $(1-\beta)$
#         - Power of test is increased by increasing the sample size.

# %%
type_error1 = Image.open('C://Users//Mohit.Kumar//Pictures//DS//type_error1.png')
type_error1.resize((900,400))
# Out:
# <PIL.Image.Image image mode=RGBA size=900x400 at 0x269E09D52B0>

# %%
#example for type1 and type2 error
type_error2 = Image.open('C://Users//Mohit.Kumar//Pictures//DS//type_error2.png')
type_error2.resize((900,400))
# Out:
# <PIL.Image.Image image mode=RGBA size=900x400 at 0x269E09D5F10>

# %% [markdown]
#     Q. You are taking a pregnancy test. The null hypothesis of this test is: I am not pregnant. In reality, you are not pregnant, but the test says you are. Which type of error occurred?
#
# >Ans. This is a Type I error. You rejected a null hypothesis that is true. It is also called a false positive, although in this case, it is counter intuitive. While usually no error is made (that’s why hypothesis testing is so wide-spread), it is impossible to make both errors at the same time.

# %% [markdown]
# ***

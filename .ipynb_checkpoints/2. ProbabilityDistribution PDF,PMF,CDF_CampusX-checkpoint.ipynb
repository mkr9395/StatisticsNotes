# %% [markdown]
# # Session 40 : Probability Distribution Functions - PDF, PMF & CDF

# %% [markdown]
# https://www.youtube.com/watch?v=C_QAURbgBqY

# %% [markdown]
# ### What are Random Variables in Stats and Probability?
#
# A Random Variable is a set of possible values from a random experiment.
#
# eg: Random Experiemnet --> throwing a dice.
#
# Sample space : {1,2,3,4,5,6}
#
# outcome (Y) : 1 or 2 or 3 or 4 or 5 or 6

# %% [markdown]
# ![probabilyity.png](attachment:probabilyity.png)

# %% [markdown]
# ### Types of random Variable :
#
# 1. __Discrete :__ Age of a person/ Outcome of a dice
#
#
# 2. __Continuous :__ CGPA in terms of decimals of 3 places.

# %% [markdown]
# ## Probability
#
# Probability is the chance of something happening, a more academic definition for this would be __the likelihood of an event occurring.__
#
# An event is a specific outcome or a combination of several outcomes. These outcomes can be pretty much anything.
#
# Having a probability of one expresses absolute certainty of the event occurring and a probability of zero expresses absolute certainty of the event not occurring. You probably figured this out, but higher probability values indicate a higher likelihood.

# %% [markdown]
# $ A = event $
#
# $ P(A) = probability $
#
# $$P(A) = \frac{Preferred\;(favourable)}{All\;(sample\;space)}$$

# %% [markdown]
# **The probability of two independent events occurring at the same time is equal to the product of all the probabilities of the individual events.**
#
# $$ P(A\;and\;B) = P(A) . P(B)$$
#
# eg: The likelihood of getting the ace of spades = (the probability of getting an ace) **times** (the probability of getting a spade.)

# %% [markdown]
# **Q. Why do we express probabilities numerically?**
#
# Our goal is to be able to compare the probabilities of events and determine which is the relatively more likely outcome.

# %% [markdown]
# **Experimental Probabilities :** The probabilities we get after conducting experiments.
# whereas the ones we introduced earlier were theoretical or true probabilities.
#
# The experimental probabilities we get are not always equal to the theoretical ones, but are a good approximation.
#
# $$P(A) = \frac{Successful\;trials}{All\;trials}$$

# %% [markdown]
# **Q. Why do we use experimental probabilities?**
#
# Because they are easy to compute and serve as good predictors for theoretical ones

# %% [markdown]
# **Expected value E(A) :** It is used to predict future events. It is The average outcome we expect if we run an experiment many times.
#
# The expected value of an event A denoted **E(A)** is the outcome we expect to occur when we run an experiment.
#
# We can use expected values to make predictions about the future based on past data.
#
# eg: *We frequently make predictions using intervals instead of specific values due to the uncertainty the future brings.*
# Meteorologists often use these when forecasting the weather, they do not know exactly how much snow,rain or wind there's going to be, so they provide us with likely intervals That is why we often hear statements like expect between three to five feet of snow tomorrow morning or temperatures rising up to 90 degrees on Wednesday.

# %% [markdown]
# **For Categorical Outcome :**
#
# For an event with categorical outcomes like suits, we calculate the expected value by multiplying the theoretical probability of the event P(A)  by the number of trials we carried out in (n).
#
# **E(A) = P(A) * n**

# %% [markdown]
# **Numerical outcome :**
#
# **A + B + C =  P(A) . A +  P(B) . B +  P(C) . C**
#
# We take the value for every element in the sample space and multiply it by its probability, then we add all of those up to get the expected value.

# %% [markdown]
# **Q. Why do we use intervals when forecasting future events?**
#
# 1. because the expected value might have a low probability of occuring.
# 2. because we want to increase the likelihood of our predictions being accurate.
# 3. because the expected value could not be attainable.

# %% [markdown]
# #### Frequency
# **What does the “frequency” of a value within the sample space represent?**
#
# The number of times the value features in a sample space.

# %% [markdown]
# **Probability frequency distribution**
#
# a collection of the probabilities for each possible outcome and how often they occur. It is usually presented through *Graphs or Tables*
#
# *Transforming the frequency of each outcome into a probability:* <br>Knowing the size of the sample space, we can determine the true probabilities for each outcome. We simply divide the frequency for each possible outcome by the size of the sample space.

# %% [markdown]
# **Note :** When making predictions, we generally want our interval to have the highest probability we can see that the individual outcomes with the highest probability are the ones with the highest bars in the graph, usually the highest bars will form around the expected value. Thus the values around it would also be the values with the highest probability.
#
# This suggests that if we want the interval with the highest probability, we should construct it around the expected value.

# %% [markdown]
# **Q.  2 standard six-sided dice, why is the probability of rolling a sum of 7 equal to one sixth?**
#
# There are 6 favourable outcomes out of 36 outcomes in the sample space so the favourable over all the formula results in 6/36 or simply 1/6

# %% [markdown]
# **Compliment P(A') :**
# a compliment of an event is everything.
#
# $P(A') = 1-P(A)$
#
# Compliment of compliment is the event itself. $P(A')' = P(A)$
# <br>eg: What is the complement of NOT rolling a 3?</br>
# Ans - Rolling a 3.

# %% [markdown]
# sum of probabilitites of A & B = P(A) + P(B)
#
# if $P(A) + P(B) + P(C) = 1$ then, we are 100% sure this event will occur

# %% [markdown]
# ## Probability Distribution:
#
# A probability distribution is a list of all of the possible outcomes of a random variable
# along with their corresponding probability values.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Types of Probability Distributions :
# ![pdf_cdf2222.png](attachment:pdf_cdf2222.png)

# %% [markdown]
# ## Probability Distribution Functions :
#
# Everytime we can't create a probability distribution table. we need a function which can be applied on too large sample space. We need a probability distribution function.
#
#
# A probability distribution function is a mathematical function that describes
# the probability of obtaining different values of a random variable in a particular
# probability distribution.
#
# $$y\;=\;f(x)$$
#
# Note - A lot of time Probability Distribution _(the table)_ and Probability Distribution Functions _(the function)_ are
# used interchangeably.

# %% [markdown]
# #### Different kind of Probability Distributions :

# %% [markdown]
# ![probability_distribution_grpahs.png](attachment:probability_distribution_grpahs.png)

# %% [markdown]
# #### Why are Probability Distributions important?
# - Gives an idea about the shape/distribution of the data.
#
#
# - And if our data follows a famous distribution then we automatically know a lot about the
# data.

# %% [markdown]
# ## Types of Probability Distribution Functions:

# %% [markdown]
# - __1. Probability Mass Function (PMF) -__ probability distribution function for discrete random variable. eg: rolling a dice
#
#
# - __2. Probability Density Function (PDF) -__ probability distribution function for continuous random varibale. eg: marks of students.
#
#
# - __3. Cummulative Distribution Function (CDF) -__ created using PMF and PDF

# %% [markdown]
# ### 1. __Probability Mass Function (PMF) :__
#
#
# - It is a mathematical function that describes the probability distribution of a ___discrete random variable.___
#
#
# - The PMF of a discrete random variable assigns a probability to each possible value
# of the random variable.
#
#
# ___The probabilities assigned by the PMF must satisfy two
# conditions:___
#
# - a. The probability assigned to each value must be non-negative (i.e., greater
# than or equal to zero).
#
#
# - b. The sum of the probabilities assigned to all possible values must equal 1

# %% [markdown]
# #### eg : Rolling a dice:
#
# mathematical equation :
#
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import random

# %%
L = []

for i in range(10000):
    L.append(random.randint(1,6))
    
len(L)
# Out:
# 10000

# %%
L[:5]
# Out:
# [6, 2, 5, 2, 1]

# %%
pd.Series(L).value_counts()
# Out:
# 4    1745
# 1    1704
# 2    1650
# 3    1635
# 6    1633
# 5    1633
# dtype: int64

# %% [markdown]
# #### Probability of each outcome

# %%
s = (pd.Series(L).value_counts()/len(L)).sort_index()

# %%
s
# probability of each number occuring
# Out:
# 1    0.1704
# 2    0.1650
# 3    0.1635
# 4    0.1745
# 5    0.1633
# 6    0.1633
# dtype: float64

# %%
s.plot(kind='bar',title = 'PMF of rolling a dice')
# Out:
# <AxesSubplot:title={'center':'PMF of rolling a dice'}>

# %% [markdown]
# #### rolling 2 dice :

# %%
L = []

for i in range(10000):
    a = random.randint(1,6)
    b = random.randint(1,6)
    
    L.append(a+b)
len(L)
# Out:
# 10000

# %%
L[:5]
# Out:
# [3, 7, 8, 2, 10]

# %% [markdown]
# ##### probability of each outcome

# %%
s = (pd.Series(L).value_counts()/len(L)).sort_index()
s
# Out:
# 2     0.0241
# 3     0.0568
# 4     0.0821
# 5     0.1114
# 6     0.1357
# 7     0.1732
# 8     0.1400
# 9     0.1142
# 10    0.0797
# 11    0.0549
# 12    0.0279
# dtype: float64

# %%
s.plot(kind='bar',title = 'PMF of rolling 2 dices together')
# Out:
# <AxesSubplot:title={'center':'PMF of rolling 2 dices together'}>

# %% [markdown]
# ##### function for probability of rolling 2 dices together (PMF):

# %% [markdown]
# ![Screenshot%202023-09-23%20211448.png](attachment:Screenshot%202023-09-23%20211448.png)

# %% [markdown]
# ### Types of PMF:
#
# - __Bernoulli Distribution :__ Models a random experiment with only two possible outcomes, typically denoted as success and failure (e.g., coin flips, yes/no events).
#
#
# - __Binomial Distribution :__ Describes the number of successes in a fixed number of independent Bernoulli trials (e.g., the number of heads in multiple coin flips).
#
#
# - __Poisson Distribution :__ Models the number of events occurring within a fixed interval of time or space, assuming events are rare and independent (e.g., the number of phone calls at a call center in an hour).

# %% [markdown]
# ### Cumulative Distribution Function (CDF) of PMF
#
# CDF describes the probability that a random variable $'X'$ with a given probability distribution will be found at a __value less than or equal to $'x'$__
#
# $$f(x)\;=\;P\;(X<=x)$$
#
# > probability Starts with 0 and ends with 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### NOTE : Difference in PMF and CDF of PMF
#
# - PMF of 5 = probability of 5 occuring
#
#
# - CDF of 5 = probility of 5 or less than 5

# %%
# this is PMF
pmf = (pd.Series(L).value_counts()/len(L)).sort_index()
pmf
# Out:
# 2     0.0241
# 3     0.0568
# 4     0.0821
# 5     0.1114
# 6     0.1357
# 7     0.1732
# 8     0.1400
# 9     0.1142
# 10    0.0797
# 11    0.0549
# 12    0.0279
# dtype: float64

# %%
# this is cdf of PMF
cdf_pmf = np.cumsum(pmf) # cummulative sum
cdf_pmf
# Out:
# 2     0.0241
# 3     0.0809
# 4     0.1630
# 5     0.2744
# 6     0.4101
# 7     0.5833
# 8     0.7233
# 9     0.8375
# 10    0.9172
# 11    0.9721
# 12    1.0000
# dtype: float64

# %%
cdf_pmf.plot(kind='bar',title='cdf of pmf of rolling 2 dices')
# Out:
# <AxesSubplot:title={'center':'cdf of pmf of rolling 2 dices'}>

# %% [markdown]
# ### 2. Probability Density Function (PDF) :
#
# PDF stands for Probability Density Function. It is a mathematical function that
# describes the probability distribution of a ___continuous random variable___
#
# __NOTE : Here on y-axis we donot show probability of an event occuring instead it is Probability Density as value of x can be infinite__
#
#
#
# ![image.png](attachment:image.png)
#
# ### <span class="girk">Here Area under the curve is probability. It is inside a range of numbers</span>

# %% [markdown]
# ### NOTE : The PDF doesn't gives the probability of a single point (as it does for discrete random variables), but rather a density or likelihood.

# %% [markdown]
# #### What does the area of this graph represents?
#
# ##### Area of the graph (blue region) : Probabilty of a student's marks between 0 to 10
#
# $$P (0 \leq X \leq 10)\;=\;1$$

# %% [markdown]
# #### Why we don't have proability values on y-axis of PDF instead have probability density values:
# > As there can be infinite values and we cannot have probability of getting each and every value as it may be close to zero. That is why in PDF on y-axis we don't have probabilities instead have probability density.

# %% [markdown]
# ##### probability of getting marks between 8 and 9 marks:

# %% [markdown]
# ![Screenshot%202023-04-24%20185056.png](attachment:Screenshot%202023-04-24%20185056.png)

# %% [markdown]
# ### How to calculate probability using PDF:
#
#
# The area under the range will give the probability. This are is calculated using integration.

# %% [markdown]
# ### Difference between Probability and Probability Density:

# %% [markdown]
# The main difference between probability and probability density is:
#
# - **Probability**: It measures the likelihood of a specific outcome or event occurring in a discrete sample space. It gives a probability value for each specific outcome and is used for discrete random variables.
#
#
#
# - **Probability Density**: It measures the likelihood of a continuous random variable taking on a particular value or falling within a specific range. It gives a probability density value for each point on the continuous spectrum and is used for continuous random variables.
#
# In summary, probability deals with discrete events and assigns probabilities to specific outcomes, while probability density deals with continuous variables and assigns probabilities to intervals or ranges of values.
#
#
#
#
# **Example - Rolling a Die**:
#
# **Probability**:
# - Suppose you have a standard six-sided die, and you want to find the probability of rolling a 3. In this case, you have a discrete set of possible outcomes: {1, 2, 3, 4, 5, 6}.
# - The probability of rolling a 3 is 1/6, because there is 1 favorable outcome (rolling a 3) out of a total of 6 possible outcomes.
# - Probability deals with specific events or outcomes, and it assigns probabilities to each outcome individually.
#
# **Probability Density**:
# - Now, consider a different scenario where you want to find the probability density of rolling a die and obtaining a result between 3 and 4 (inclusive) on a continuous scale.
# - In this case, you are working with continuous values within a range: [3, 4].
# - The probability density function (PDF) for this continuous interval is constant because each value within the interval has an equal likelihood of occurring.
# - The probability density within this range would be 1/(4 - 3) = 1, indicating a constant density for this interval.
# - Probability density deals with continuous variables and assigns probabilities to intervals or ranges of values, rather than individual specific outcomes.
#
# In summary:
#
# - **Probability** deals with discrete events and assigns probabilities to specific outcomes (e.g., the probability of rolling a 3 on a die).
# - **Probability Density** deals with continuous variables and assigns probabilities to intervals or ranges of values (e.g., the probability density of rolling a die and getting a result between 3 and 4 on a continuous scale).

# %% [markdown]
# ### Types of PDF:
#
#
# - __Normal (Gaussian) Distribution :__ Often referred to as the "bell curve," it is characterized by a symmetric, bell-shaped curve. Many natural phenomena follow this distribution (e.g., heights of people, errors in measurements).
#
#
# - __Exponential Distribution :__ Describes the time between events in a Poisson process, where events occur at a constant average rate (e.g., time between arrivals at a bus stop).
#
#
# - __Uniform Distribution :__ All values within a specified range are equally likely (e.g., rolling a fair six-sided die).
#
#
# - __Log-Normal Distribution :__ The logarithm of the data follows a normal distribution, often used for data that spans several orders of magnitude (e.g., stock prices).

# %% [markdown]
# #### PDF of normal distribution :
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### CDF of normal distribution :
# ![cumulative_distri222.png](attachment:cumulative_distri222.png)

# %% [markdown]
# ### Difference between PMF and PDF:

# %% [markdown]
# The main difference between a Probability Mass Function (PMF) and a Probability Density Function (PDF) lies in the type of data they are used for:
#
# 1. **Probability Mass Function (PMF)**:
#    - Used for **discrete data**, which means data that takes on distinct, separate values.
#    - PMF assigns probabilities to specific individual values in the data.
#    - It gives the probability of a random variable taking on a particular value.
#    - on y-axis we have values of probabilities
#
#
#
# 2. **Probability Density Function (PDF)**:
#    - Used for **continuous data**, which means data that can take on any value within a range.
#    - PDF assigns probabilities to intervals or ranges of values rather than specific values.
#    - It gives the probability of a random variable falling within a particular range.
#    - on y-axis we have values of density of probabilities
#
# In short, PMF deals with discrete data and assigns probabilities to specific values, while PDF deals with continuous data and assigns probabilities to intervals or ranges of values.

# %% [markdown]
# ### <span class="mark">Density Estimation - use to calculate PDFs</span>
#
# Density estimation is a statistical technique used to estimate the probability density function (PDF) of a random variable based on a set of observations or data. In simpler terms, it involves estimating the underlying distribution of a set of data points.
#
#
# Density estimation  is often used to estimate the probability distribution of input data or to model the likelihood of certain events or outcomes.
#
#
# There are various methods for density estimation, __including parametric and non-parametric approaches.__
#
# - __Parametric methods__ assume that the data follows a specific probability distribution (such as a normal distribution), while
#
#
# - __Non-parametric methods__ do not make any assumptions about the distribution and instead estimate it directly from the data.
#
# <br></br>
#
# Commonly used techniques for density estimation include
# - __Kernel Density Estimation (KDE)__
# - __Histogram estimation__
# - __Gaussian mixture models (GMMs)__

# %% [markdown]
# ### 1. Parametric Density Estimation
# Parametric density estimation is a method of estimating the probability density
# function (PDF) of a random variable by assuming that the underlying distribution
# belongs to a specific parametric family of probability distributions, such as the
# normal, exponential, or Poisson distributions.
#
# ___It is called Parameteric as we plot distribution using parameters such as mean and std___

# %%
import matplotlib.pyplot as plt
from numpy.random import normal
import seaborn as sns

sample = normal(loc=50, scale=5, size=1000)

# %%
sample
# Out:
# array([49.05039729, 54.26573278, 48.27894667, 61.36273158, 54.80135883,
#        52.32098335, 47.53004877, 50.7753917 , 50.41999369, 52.77578169,
#        46.44714238, 58.28164546, 56.2033892 , 47.37088615, 41.61231126,
#        50.61189703, 47.49975306, 56.59985233, 49.33321643, 46.33787137,
#        54.21976047, 43.19589848, 50.97247551, 55.62008937, 45.53081229,
#        49.36535276, 52.21093087, 44.64503405, 46.6326014 , 44.30725369,
#        50.8472978 , 52.51254762, 51.48812508, 46.63757728, 56.96733389,
#        48.39765526, 52.61142404, 58.30902865, 51.50096502, 47.80897241,
#        41.74243314, 51.53325333, 48.67688438, 53.49930272, 47.06179125,
#        44.30527632, 48.75587242, 44.98571266, 52.65927526, 35.54131429,
#        48.60424362, 54.34281174, 51.8506321 , 47.67957292, 53.67328424,
#        56.44236695, 49.97683486, 55.17482309, 49.94661142, 51.05162787,
#        50.50785054, 47.77783377, 50.18268666, 54.40245679, 44.79178377,
# ...

# %% [markdown]
# ##### plot histogram to understand the distribution of data:

# %%
plt.hist(sample, bins=10)
# Out:
# (array([  6.,  27., 107., 250., 299., 213.,  77.,  18.,   2.,   1.]),
#  array([33.06470353, 36.93287725, 40.80105097, 44.66922469, 48.53739841,
#         52.40557213, 56.27374585, 60.14191957, 64.01009329, 67.87826701,
#         71.74644073]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ###### calculate sample mean and sample std dev

# %%
sample_mean, sample_std = sample.mean(), sample.std()

# %% [markdown]
# ###### fit the distribution with the above parameters

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from scipy.stats import norm
dist = norm(sample_mean, sample_std) # creating normal distribution with the sample mean and sample std dev

# %%
sample.min(), sample.max()
# Out:
# (33.06470353186518, 71.74644073112997)

# %% [markdown]
# ##### generating 100 data points (x) in range of min and max :

# %%
values = np.linspace(sample.min(),sample.max(),100)
values
# Out:
# array([33.06470353, 33.45542815, 33.84615277, 34.23687739, 34.627602  ,
#        35.01832662, 35.40905124, 35.79977586, 36.19050048, 36.5812251 ,
#        36.97194971, 37.36267433, 37.75339895, 38.14412357, 38.53484819,
#        38.9255728 , 39.31629742, 39.70702204, 40.09774666, 40.48847128,
#        40.8791959 , 41.26992051, 41.66064513, 42.05136975, 42.44209437,
#        42.83281899, 43.2235436 , 43.61426822, 44.00499284, 44.39571746,
#        44.78644208, 45.1771667 , 45.56789131, 45.95861593, 46.34934055,
#        46.74006517, 47.13078979, 47.5215144 , 47.91223902, 48.30296364,
#        48.69368826, 49.08441288, 49.4751375 , 49.86586211, 50.25658673,
#        50.64731135, 51.03803597, 51.42876059, 51.8194852 , 52.21020982,
#        52.60093444, 52.99165906, 53.38238368, 53.7731083 , 54.16383291,
#        54.55455753, 54.94528215, 55.33600677, 55.72673139, 56.117456  ,
#        56.50818062, 56.89890524, 57.28962986, 57.68035448, 58.0710791 ,
# ...

# %%
# calculating PDF of each value 
probability_density= [dist.pdf(value) for value in values]
probability_density
# Out:
# [0.00029027644401954564,
#  0.00037498507955461993,
#  0.0004815229772230555,
#  0.0006146400812525113,
#  0.0007798760330156537,
#  0.0009836285018431125,
#  0.001233211225434342,
#  0.0015368966655683284,
#  0.001903937560768088,
#  0.002344561176638351,
#  0.0028699297822659424,
#  0.0034920608855059628,
#  0.004223701107700777,
#  0.005078148329058402,
#  0.006069017936431156,
#  0.007209950683402743,
#  0.00851426183098221,
#  0.009994533847616765,
#  0.011662157946408706,
#  0.013526833024629228,
#  0.015596034007686485,
#  0.0178744650139465,
#  0.02036351594713939,
#  0.023060743869390613,
#  0.025959402583414833,
#  0.02904804503847733,
#  0.032310223277412696,
#  0.03572430950896561,
#  0.03926345942652118,
#  0.042895735078231446,
#  0.04658439948404808,
#  0.050288388939095215,
#  0.05396296177387687,
#  0.05756051457345874,
#  0.061031548869374806,
#  0.06432576353503418,
#  0.06739324098426978,
#  0.07018568923229825,
#  0.07265769733002722,
#  0.074767958960741,
# ...

# %%
plt.hist(sample,bins=10,density=True)
plt.plot(values,probability_density)

# %% [markdown]
# #### OR using SNS

# %%
sns.distplot(sample)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### Non-Parametric Density Estimation (KDE)
#
# But sometimes the distribution is not clear or it's not one of the famous distributions.
#
#
# - Non-parametric density estimation is a statistical technique used to estimate the probability
# density function of a random variable without making any assumptions about the underlying
# distribution.
#
#
# - It is also referred to as non-parametric density estimation because __it does not
# require the use of a predefined probability distribution function, as opposed to parametric
# methods such as the Gaussian distribution.__
#
#
# - The non-parametric density estimation technique involves constructing an estimate of the
# probability density function using the available data. This is typically done by creating a __kernel
# density estimate.__

# %% [markdown]
# ##### Advantage of Non-parametric density estimation over parametric density estimation:
#
# - One of the main advantages is that it does not require the assumption of a specific distribution, which allows for more flexible and accurate estimation in situations where the underlying distribution is unknown or complex.
#
# ##### Disadvantage of Non-parametric density estimation over parametric density estimation:
# - Non-parametric density
# estimation can be computationally intensive and may require more data to achieve accurate
# estimates compared to parametric methods.

# %% [markdown]
# ### Kernel Density Estimate(KDE)
#
# The KDE technique involves using a __kernel function to smooth out the data__ and create a
# continuous estimate of the underlying density function.
#
# here we are using gaussian kernel:

# %% [markdown]
# ![Screenshot%202023-09-23%20224126.png](attachment:Screenshot%202023-09-23%20224126.png)

# %% [markdown]
# - ___considering each data point as centre(or mean) and create a Gaussian kernal around it.___
#
#
# - ___moving on y-axis and summing proability denisities of each peak of Gaussian kernal which has same x-points.___

# %% [markdown]
# ### KDE uses bandwidth (bw_adjust) to control peakedness

# %% [markdown]
# ### steps to calculate KDE:
#
#  Suppose we have the following dataset of ages: [25, 27, 30, 33, 35, 36].
#
# Step 1: Data Preparation
# - Start with the dataset: Ages = [25, 27, 30, 33, 35, 36].
#
# Step 2: Choose a Kernel Function
# - Select a kernel function. For this example, we'll use a Gaussian (normal) kernel, which is commonly used in KDE. The Gaussian kernel is defined as: K(u) = (1 / √(2π)) * e^(-u^2 / 2), where u is a variable.
#
# Step 3: Choose a Bandwidth (Smoothing Parameter, like $\sigma$ in case of normal distribution)
# - Select a bandwidth parameter (h). Let's choose h = 2 for this example. This bandwidth determines the width of the kernel and influences the smoothness of the estimate.
#
# Step 4: Calculate Kernels for Each Data Point
# - For each data point in the dataset, we apply the Gaussian kernel centered at that point with the chosen bandwidth. Let's calculate the kernels for each data point:
#
#    - For the data point 25:
#      K(x) = (1 / √(2π)) * e^(-(x - 25)^2 / (2 * 2^2)) = 0.054
#
#    - For the data point 27:
#      K(x) = (1 / √(2π)) * e^(-(x - 27)^2 / (2 * 2^2)) = 0.119
#
#    - Continue this calculation for each data point.
#
# Step 5: Sum the Kernels
# - Sum all the individual kernels calculated in Step 4 for each data point. This results in a continuous curve representing the estimated probability density.
#
#    - At age 25, the density is 0.054.
#    - At age 27, the density is 0.119.
#    - Continue this process for all data points.
#
# Step 6: Normalize the Result
# - To ensure that the estimated density integrates to 1, divide the entire curve by the total number of data points (6) and the bandwidth (2).
#
# Step 7: Plot the KDE Curve
# - Finally, plot the resulting KDE curve on a graph to visualize the estimated probability density of the ages.
#
# The plotted KDE curve will provide a smooth representation of how ages are likely to be distributed across the age range, with higher densities indicating where data points are more concentrated.
#
# In this example, we used a Gaussian kernel with a bandwidth of 2 to estimate the probability density of ages based on the given dataset. The KDE curve will show the shape and smoothness of the estimated age distribution.

# %%
# generate a sample
sample1 = normal(loc=20, scale=5, size=300)
sample2 = normal(loc=40, scale=5, size=700)
sample = np.hstack((sample1, sample2))

# %%
len(sample)
# Out:
# 1000

# %%
sample # 100 points
# Out:
# array([26.42046763, 20.17277584, 29.27103061, 17.31706632, 14.62781419,
#        12.34026796, 27.53036823, 18.37578191, 18.32605155, 20.05803587,
#        23.88233316, 16.16105066, 22.49459924, 10.20646396, 18.75988799,
#        26.19759001, 16.41674523, 19.77738783, 23.01320536, 19.55240968,
#        17.74427015, 28.82045758, 14.5733133 , 19.8936264 , 13.65039463,
#        21.41951556, 20.23476825, 14.76528411, 23.52137268, 23.28176305,
#        20.27773314, 22.63936538, 22.45007296, 15.58819406, 21.34811362,
#        13.52183529, 11.75956874, 20.48449616, 16.4285402 , 21.2846476 ,
#        28.43188148, 20.09638549, 13.27802405, 24.91066322, 20.21096702,
#        15.57622727, 18.03112824, 17.65987497, 17.00065056, 20.29389739,
#        21.73756886, 17.37135845, 25.28426497, 18.55618083,  9.59972036,
#        17.09877635, 20.56358562, 21.49153272, 21.44390971, 20.98112992,
#        34.03727113, 23.89170634, 17.00150238, 22.359492  , 18.19582252,
# ...

# %%
# plot histogram bins=50
plt.hist(sample,bins=50)
# Out:
# (array([ 2.,  0.,  1.,  1.,  1.,  2.,  5.,  9., 14., 12., 10., 18., 23.,
#         31., 22., 28., 28., 18., 23., 14., 15., 10., 10., 15.,  8., 21.,
#         27., 25., 30., 31., 49., 52., 72., 63., 58., 37., 48., 52., 31.,
#         26., 19., 13., 11.,  4.,  6.,  2.,  1.,  0.,  1.,  1.]),
#  array([ 3.54796482,  4.63710389,  5.72624296,  6.81538203,  7.9045211 ,
#          8.99366017, 10.08279924, 11.1719383 , 12.26107737, 13.35021644,
#         14.43935551, 15.52849458, 16.61763365, 17.70677272, 18.79591179,
#         19.88505086, 20.97418993, 22.063329  , 23.15246807, 24.24160714,
#         25.33074621, 26.41988528, 27.50902435, 28.59816341, 29.68730248,
#         30.77644155, 31.86558062, 32.95471969, 34.04385876, 35.13299783,
#         36.2221369 , 37.31127597, 38.40041504, 39.48955411, 40.57869318,
#         41.66783225, 42.75697132, 43.84611039, 44.93524945, 46.02438852,
#         47.11352759, 48.20266666, 49.29180573, 50.3809448 , 51.47008387,
# ...

# %% [markdown]
# #### graph not following any particular distribution so we will use KDE (non-parametric)

# %% [markdown]
# #### Applying KDE and kernal as Gaussian :

# %%
from sklearn.neighbors import KernelDensity

# bandwidth gives spread (std dev) of the graph. 

model = KernelDensity(bandwidth=3, kernel='gaussian') # by deafult it is gaussian

# %% [markdown]
# ### NOTE : higher bandwidth gives flatter graphs and lower bandwidth give peaked graphs

# %%
# convert data to a 2D array for KDE to work
sample = sample.reshape((len(sample), 1))

model.fit(sample)
# Out:
# KernelDensity(bandwidth=3)

# %% [markdown]
# ##### genearting 100 points between min and max

# %%
values = np.linspace(sample.min(),sample.max(),100)
values = values.reshape((len(values), 1)) # converting those 100 points to 2-D

# %%
probabilities = model.score_samples(values) # will give log values

# %%
# calculating exponential value of each probability as it converts log values to normal

probabilities = np.exp(probabilities)

# %% [markdown]
# `score_samples(values)` returns the log-density estimate of the input samples values.
#
# This is because the `score_samples()` method of the KernelDensity class returns the logarithm of the probability density estimate rather than the actual probability density estimate.

# %%
plt.hist(sample, bins=50, density=True)
plt.plot(values[:], probabilities)
plt.show()

# %%
sns.kdeplot(sample.reshape(1000))
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# #### Using seaborn and changing bandwidths :

# %%
sns.kdeplot(sample.reshape(1000),bw_adjust=3)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(sample.reshape(1000),bw_adjust=5)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(sample.reshape(1000),bw_adjust=0.02)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# #### OR using Seaborn

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.kdeplot(df['petal_length'],hue=df['species'])
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Density'>

# %% [markdown]
# According to PDF:
#
# - __We can clearly distinguish that petal_length < 2 will be setosa__
#
#
#
# - __We can clearly distinguish that petal_length between 2 and 4 will be versicolor__
#
#
# - __and from 5 beyond, high chances of it being virginica__

# %%
sns.kdeplot(df['petal_width'],hue=df['species'])

# cdf plot:
sns.ecdfplot(data=df,x='petal_width',hue='species')
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='Density'>

# %% [markdown]
# According to CDF:
#
# - __99% chance that a versicolor petal_width will have petal_width less than 1.7__
#
#
# - __for green i.e virginca, only 10% of chance that a flower petal_width will be less than 1.7 and 90% of chance that petal_width will be greater than 1.7__

# %% [markdown]
# ### Cumulative Distribution Function(CDF) of PDF

# %% [markdown]
# ##### for 165 :
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### NOTE
#
# - __Area of PDF gives CDF (Integration on PDF gives CDF)__
#
#
# - __slope of CDF for each point makes the PDF (Differentiation on CDF gives PDF)__

# %% [markdown]
# CDF is especially useful when we want to estimate the probability of some interval.Graphically, the area under the density curve would represent the chance of getting a value within that interval. We find this area by computing the integral of the density curve over the interval from A to B.
# $$\int_a^b p(x)dx$$
#
#
#
#
# $$PDF \longrightarrow CDF \int_ {-\infty}^y p(y)dy = F(y) \Longrightarrow Integration\;\text{(Area under curve of PDF)}$$
# <br></br>
# $$CDF \longrightarrow PDF\;\;p(y)=F(y)\frac{d}{dy}  \leftarrow Derivative\;(Slope\;of\;CDF\;using\;Differentitation)$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ___

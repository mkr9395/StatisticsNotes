# %% [markdown]
# # WEEK 21 : Chi-square

# %% [markdown]
# https://learnwith.campusx.in/s/courses/637339afe4b0615a1bbed390/take
#
#
# https://www.cliffsnotes.com/study-guides/statistics/bivariate-relationships/chi-square-x2

# %% [markdown]
# ## Chi-square distribution $(\chi ^2)$

# %% [markdown]
# - The Chi-Square distribution, is a __continuous
# probability distribution__ that is widely used in statistical hypothesis testing,
# particularly in the context of<br></br>
#      - __goodness-of-fit tests__ and <br></br>
#      - __tests for independence__ in contingency tables.
#
#
# - The Chi-Square distribution has a single parameter, the degrees of freedom (df),
# which influences the shape and spread of the distribution.
#
#
# $$Denoted\;by\;\; \chi^2*(k)$$
# $$Y \sim\;\chi^2*(k)$$
#
#    we denote chi square distribution as the capital Greek letter $\chi$ squared, followed by a parameter k depicting the degrees of freedom.
#
#
#
# - __It is taking sample from a normal distribution and squaring it. The KDE of it is chi-sqaure$(\chi ^2 = N^2)$__<br></br>
#
#
# - __The degree of
# freedom are typically associated with the number of independent variables or
# constraints in a statistical problem.__ i.e how many normal distributions we are squaring and adding together.<br></br>
#    - df = 1  sum of sqaure of single Normal distribution<br></br>
#
#    - df = 2 when we perform sum of sqaure of two Normal distrutions<br></br>
#
#    - df = 3 when we perform  sum of sqaure of three Normal distrutions
#
#
# __for very high degree of freedom, chi-square distribution becomes similar to NORMAL DISTRIBUTION__

# %% [markdown]
# ### NOTE : As degree of freedom increases, the graph becomes more right skewed

# %% [markdown]
# ### __Some key properties of the Chi-Square distribution are:__
# - It is a continuous distribution, defined for non-negative values.
#
#
# - It is positively skewed, with the degree of skewness decreasing as the
# degrees of freedom increase.
#
#
# - __The mean of the Chi-Square distribution is equal to its degrees of
# freedom, and its variance is equal to twice the degrees of freedom.__
#     - $\mu = k$
#     - $\sigma = \sqrt{2k}$ where k is degree of freedom
#
#
# - As the degrees of freedom increase, the Chi-Square distribution
# approaches the normal distribution in shape.
#
#
# The Chi-Square distribution is used in various statistical tests, such as
#
# - __the Chi- Square goodness-of-fit test__, which evaluates whether an observed frequency
# distribution fits an expected theoretical distribution, and
#
#
# - the __Chi-Square test for independence__, which checks the association between categorical variables in a
# contingency table.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Generate a sample of 100 numbers from a standard normal distribution with mean as 0 and std dev=1

# each sample size of normal distribution is 100 here

sample1 = np.random.normal(loc=0, scale=1, size=100) 
sample2 = np.random.normal(loc=0, scale=1, size=100)
sample3 = np.random.normal(loc=0, scale=1, size=100)
sample4 = np.random.normal(loc=0, scale=1, size=100)
sample5 = np.random.normal(loc=0, scale=1, size=100)

# %% [markdown]
# #### squaring the points and adding them:

# %%
x = sample1**2                                           # degree of freedom = 1
y = sample1**2 + sample2**2                              # degree of freedom = 2
z = sample1**2 + sample2**2 + sample3**2                 # degree of freedom = 3
u = sample1**2 + sample2**2 + sample3**2 + sample4**2    # degree of freedom = 4
v = sample1**2 + sample2**2 + sample3**2 + sample4**2 + sample5**2  # degree of freedom = 5

# %% [markdown]
# #### Kde of 1st normal distribution being squared

# %%
sns.kdeplot(x,clip=(x.min(),x.max()))
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# #### for 2N normally distributed graphs:

# %% [markdown]
# - x = $\text{sample 1}^2$                  $\rightarrow$ degree of freedom = 1
# - y = $\text{sample 1}^2 + \text{sample 2}^2$     $\rightarrow$ degree of freedom = 2

# %%
sns.kdeplot(x, clip=(x.min(),x.max()))
sns.kdeplot(y, clip=(y.min(),y.max()))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(x, clip=(x.min(), x.max()), label='X - squared sum of 1 Normal distribution')
sns.kdeplot(y, clip=(y.min(), y.max()), label='Y - squared sum of 2 Normal distribution')
sns.kdeplot(z, clip=(z.min(), z.max()), label='Z - squared sum of 3 Normal distribution')
sns.kdeplot(u, clip=(u.min(), u.max()), label='U - squared sum of 4 Normal distribution')
sns.kdeplot(v, clip=(v.min(), v.max()), label='V - squared sum of 5 Normal distribution')

# Display the legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## Chi Square Test - for categorical variables

# %% [markdown]
# - It is a non paramteric test which means it doesnot have any assumptions about the data.
#
#
#
# - The Chi-Square test is a statistical hypothesis test used to determine :<br></br>
#
#     - if there is a significant association __between categorical variables__ or<br></br>
#
#     - if an observed distribution of categorical data differs from an expected theoretical distribution.
#
#
# These 2 test are based on chi-square distribution.

# %% [markdown]
# ### NOTE : condition to check before applying chi-square test : Each category should have an expected frequency of at least 5.

# %% [markdown]
# ## chi-square test has 2 types:
#
#
# ### 1. Chi-Square Goodness-of-Fit Test :
#
# - This test is used to determine if the __observed
# distribution of a single categorical variable__ matches an expected theoretical distribution.
#
#
# - eg : rolling a die follows a uniform distribution or not
#
#
#
# - It is often applied to check if the data follows a specific probability distribution, __such as
# the uniform or binomial distribution etc__<br></br>
#
#    - ___requires 1 categorical column___
#
#
# -  It answers questions like: "Do the observed frequencies match the expected frequencies according to a theoretical distribution or hypothesis?"
#
#
#
# ![Screenshot%202023-05-08%20021224.png](attachment:Screenshot%202023-05-08%20021224.png)

# %% [markdown]
# ### 2. Chi-Square Test for Independence (Chi-Square Test for Association):
#
# This test is used to
# determine whether there is a significant association between __two categorical variables__ in
# a sample.
#    - ___requires 2 categorical columns. Determines are they independent or dependent___
#
#
# eg : in titanic dataset dieing is related to p-class or not

# %% [markdown]
# ### 1. Goodness of Fit Test

# %% [markdown]
# The Chi-Square Goodness-of-Fit test is a statistical hypothesis test used to
# determine if the observed distribution of a single categorical variable
# matches an expected theoretical distribution.
#
#
# It helps to evaluate
# whether the data follows a specific probability distribution, such as
# uniform, binomial, or Poisson distribution, among others. This test is
# particularly useful when you want to assess if the sample data is
# consistent with an assumed distribution or if there are significant
# deviations from the expected pattern.

# %% [markdown]
# ### Steps:
#
#
# The Chi-Square Goodness-of-Fit test involves the following steps:
#
# 1. ___Decide which distribution the theoretical values will follow and calculate the theoretical values accordingly___
#
#
# 2. __Define the null hypothesis (H0) and the alternative hypothesis (H1):__
#     - H0: The observed data follows the expected theoretical distribution.<br></br>
#
#     - H1: The observed data does not follow the expected theoretical distribution.
# <br></br>
#
# 3. __Calculate the theoretical frequencies (ideally how much should have come) for each category based on the
# theoretical distribution and the sample size.__
#
#
# 4. __Compute the Chi-Square test statistic (χ2) by comparing the theoretical
# and observed frequencies.__

# %% [markdown]
#
# ![Screenshot%202023-09-27%20014132.png](attachment:Screenshot%202023-09-27%20014132.png)

# %% [markdown]
#
# ### The test statistic is calculated as:

# %% [markdown]
# $$\text{Formula for Chi-Square test Statistics :}$$
#
# $$\chi^2 = \sum{\frac{(f_o\;-\;f_e)^2}{f_e}}$$
#
#
# $where\;f_o\longrightarrow\;\text{frequency of observed}$
#
# $where\;f_e\longrightarrow\;\text{frequency of theoretical}$

# %% [markdown]
# ![Screenshot%202023-09-27%20014716.png](attachment:Screenshot%202023-09-27%20014716.png)

# %% [markdown]
# 5. __where $f_o$ is the observed frequency in category o, $f_e$ is the theoretical
# frequency in category e, and the summation is taken over all
# categories.__
#
#
# 6. __Determine the degrees of freedom (df), which is typically the
# number of categories minus one (df = k - 1), where k is the number
# of categories.__
#
#
# 7. __Calculate the p-value for the test statistic using the Chi-Square
# distribution with the calculated degrees of freedom.__
#
#
# 8. __Compare the test statistic to the critical value or the p-value__

# %% [markdown]
# ![Screenshot%202023-05-08%20031505.png](attachment:Screenshot%202023-05-08%20031505.png)

# %% [markdown]
# ### Assumptions
#
# 1. __Independence:__ The observations in the sample must be independent
# of each other. This means that the outcome of one observation
# should not influence the outcome of another observation.
#
#
# 2. __Categorical data:__ The variable being analysed must be categorical,
# not continuous or ordinal. The data should be divided into mutually
# exclusive and exhaustive categories.
#
#
# 3. __Expected frequency:__ Each category should have an expected frequency of at least 5. This guideline helps ensure that the Chi-Square distribution is a reasonable approximation for the distribution of the test statistic. Having small expected frequencies can lead to an inaccurate estimation of the Chi-Square distribution,
#     potentially increasing the likelihood of a Type I error (incorrectly
#     rejecting the null hypothesis) or a Type II error (incorrectly failing to
#     reject the null hypothesis).
#
#
#
# 4. __Fixed distribution:__ ___The theoretical distribution being compared to
# the observed data should be specified before the test is conducted.___
# It is essential to avoid choosing a distribution based on the observed
# data, as doing so can lead to biased results.

# %% [markdown]
# ### __NOTE :  The Chi-Square Goodness-of-Fit test is a  non-parametric test.__
#
# Non-
# parametric tests do not assume that the data comes from a specific probability distribution or make any assumptions about population
# parameters like the mean or standard deviation.
#
#
# In the Chi-Square Goodness-of-Fit test, we compare the observed
# frequencies of the categorical data to the expected frequencies based on
# a hypothesized distribution. The test doesn't rely on any assumptions
# about the underlying distribution's parameters. Instead, it focuses on comparing observed counts to expected counts, making it a non-
# parametric test.

# %% [markdown]
# ### Example 1 (godness of fit):
#
# Suppose we have a six-sided fair die, and we want to test if the die is indeed fair. We roll the
# die 60 times and record the number of times each side comes up. We'll use the Chi-Square
# Goodness-of-Fit test to determine if the observed frequencies are consistent with a fair die
# (i.e., a uniform distribution of the sides).
#
#
# Observed frequencies for all values:
# - ○ Side 1: 12 times
# - ○ Side 2: 8 times
# - ○ Side 3: 11 times
# - ○ Side 4: 9 times
# - ○ Side 5: 10 times
# - ○ Side 6: 10 times

# %% [markdown]
# - __we will assume that the fair dice follows a normal distribution__
#
#
# - ${H_o}$ : die is fair
#
#
#
# - $H_1$: die is not fair
#
#
# - $\alpha=0.05$
#
#
#
# - __Observed values $f_0$__: sum of all outcomes = 12 + 8 + 11 + 9 + 10 + 10 = 60
#
#
# - __Expected/theoretical values $f_e$__ : as it follows normal distribution so probability of each outcome will be $60 * \frac{1}{6}=10\;times$
#
# <br></br>
# $$\chi^2=\frac{(12-10)^2+(8-10)^2+(11-10)^2+(9-10)^2+(10-10)^2+(10-10)^2}{10}=\frac{10}{10}=1$$
#
# $$(test-statistics)\longrightarrow \chi^2\;=1$$
#
# <br></br>
# number of categories = 6
#
# - __so degree of freedom =__ $n-1=6-1=5$

# %% [markdown]
# ![Screenshot%202023-05-08%20033812.png](attachment:Screenshot%202023-05-08%20033812.png)

# %% [markdown]
# since $\alpha=0.05$ and p-value = 0.9625.
#
# __so we cannot reject the null hypothesis as p-value > 0.05. So it is a fair die__

# %% [markdown]
# #### using python :

# %%
import numpy as np
import scipy.stats as stats

# %%
# Observed frequencies
observed_frequencies = np.array([12, 8, 11, 9, 10, 10])
observed_frequencies
# Out:
# array([12,  8, 11,  9, 10, 10])

# %%
# Expected frequencies for a fair die (uniform distribution)
expected_frequencies = np.array([10, 10, 10, 10, 10, 10])
expected_frequencies
# Out:
# array([10, 10, 10, 10, 10, 10])

# %%
# Calculate the chi-square statistic
chi_square_statistic = np.sum((observed_frequencies - expected_frequencies) ** 2 / expected_frequencies)
chi_square_statistic
# Out:
# 1.0

# %%
# Degrees of freedom (number of categories - 1)
degrees_of_freedom = len(observed_frequencies) - 1
degrees_of_freedom
# Out:
# 5

# %%
# Set the significance level (alpha)
alpha = 0.05

# %%
# Calculate the critical value from the chi-square distribution
critical_value = stats.chi2.ppf(1 - alpha, degrees_of_freedom)
critical_value
# Out:
# 11.070497693516351

# %% [markdown]
# ####  NOTE : `1 - stats.chi2.cdf(chi_square_statistic, degrees_of_freedom)`
#
# #### and `stats.chi2.sf(chi_square_statistic, degrees_of_freedom)` are same.  i.e `chi2.sf = 1-chi2.cdf`

# %%
# Calculate the p-value
p_value = 1 - stats.chi2.cdf(chi_square_statistic, degrees_of_freedom)
p_value
# Out:
# 0.9625657732472964

# %%
# same p-value
stats.chi2.sf(chi_square_statistic, degrees_of_freedom)
# Out:
# 0.9625657732472964

# %%
# Print the results
print(f"Chi-Square Statistic: {chi_square_statistic}")
print(f"Critical Value: {critical_value}")
print(f"P-value: {p_value}")
# Out:
# Chi-Square Statistic: 1.0
# Critical Value: 11.070497693516351
# P-value: 0.9625657732472964

# %%
# Check if the null hypothesis is rejected
if chi_square_statistic > critical_value:
    print("Reject the null hypothesis. The die is not fair.")
else:
    print("Fail to reject the null hypothesis. The die appears to be fair.")
# Out:
# Fail to reject the null hypothesis. The die appears to be fair.

# %% [markdown]
# ### Example 2 :
#
# Suppose a marketing team at a retail company wants to understand the distribution of visits to
# their website by day of the week. They have a hypothesis that visits are uniformly distributed
# across all days of the week, meaning they expect an equal number of visits on each day. They
# collected data on website visits for four weeks and want to test if the observed distribution
# matches the expected uniform distribution.
#
#
# Observed frequencies (number of website visits per day of the week for four weeks):
#
# -  Monday: 420
# -  Tuesday: 380
# -  Wednesday: 410
# -  Thursday: 400
# -  Friday: 410
# -  Saturday: 430
# -  Sunday: 390

# %% [markdown]
# - __we will assume that the fair dice follows a uniform distribution__
#
#
# - ${H_o}$ : visits are uniform distribution
#
#
#
# - $H_1$: visits are not uniform distribution
#
#
#
# - $\alpha=0.05$
#
#
#
# - __Observed values $f_0$__: sum of all outcomes = 420 + 380 + 410 + 400 + 410 + 430 + 390 = 2840
#
#
# - __Expected values $f_e$__ : as it follows normal distribution so probability of each outcome will be $2840 * \frac{1}{7}=406$
# <br></br>
#
# $$\chi^2=\frac{(420-406)^2+(380-406)^2+(410-406)^2+(400-406)^2+(410-406)^2+(430-406)^2+(390-406)^2}{406}=\frac{1672}{406}=4.12$$
#
# <br><br>
# number of categories = 7
#
# - __so degree of freedom =__ $n-1=7-1=6$

# %%
import numpy as np
from scipy import stats

# %%
observed_frequencies = np.array([420, 380, 410, 400, 410, 430, 390])
observed_frequencies
# Out:
# array([420, 380, 410, 400, 410, 430, 390])

# %%
1/7*(sum(observed_frequencies))
# Out:
# 405.71428571428567

# %%
expected_frequencies = np.array([1/7*(sum(observed_frequencies))]*7)
expected_frequencies
# Out:
# array([405.71428571, 405.71428571, 405.71428571, 405.71428571,
#        405.71428571, 405.71428571, 405.71428571])

# %%
chi_square_statistic = np.sum((observed_frequencies - expected_frequencies)**2)/(expected_frequencies[1])
chi_square_statistic
# Out:
# 4.366197183098591

# %%
degrees_of_freedom = len(expected_frequencies)-1
degrees_of_freedom
# Out:
# 6

# %%
alpha = 0.05

# %%
critical_value = stats.chi2.ppf(1-alpha,degrees_of_freedom)
critical_value
# Out:
# 12.591587243743977

# %%
p_value = 1 - stats.chi2.cdf(chi_square_statistic,degrees_of_freedom)
p_value
# Out:
# 0.6272491491065606

# %%
# Print the results
print(f"Chi-Square Statistic: {chi_square_statistic}")
print(f"Critical Value: {critical_value}")
print(f"P-value: {p_value}")
# Out:
# Chi-Square Statistic: 4.366197183098591
# Critical Value: 12.591587243743977
# P-value: 0.6272491491065606

# %%
# Check if the null hypothesis is rejected
if chi_square_statistic > critical_value:
    print("Reject the null hypothesis. The observed distribution is significantly different from the expected uniform distribution.")
else:
    print("Fail to reject the null hypothesis. The observed distribution is consistent with the expected uniform distribution.")
# Out:
# Fail to reject the null hypothesis. The observed distribution is consistent with the expected uniform distribution.

# %% [markdown]
# since $\alpha=0.05$ and p-value = 0.627.
#
# __so we cannot reject the null hypothesis as p-value > 0.05. So it is a uniform distribution. Everyday same of amount of people are visiting the website__

# %% [markdown]
# ### Example : 3 binomial distribution
# ![Screenshot%202023-05-08%20040555.png](attachment:Screenshot%202023-05-08%20040555.png)

# %% [markdown]
# - __It follows Binomial distribution where p = 0.5 and q = 0.5__
#
#
# - ${H_o}$ : probability of male p(m) and female p(f) = 50% = 0.5 and istribution is a binomial distribution
#
#
#
# - $H_1$: probability of male p(m) and female p(f) is not equal and it deosnot follow binomial distribution
#
#
#
# - $\alpha=0.05$
#
# <br><br>
# number of categories = 5 (number of children each family has 0,1,2,3,4)
#
# - __so degree of freedom =__ $n-1=5-1=4$

# %% [markdown]
# ![Screenshot%202023-05-08%20041713.png](attachment:Screenshot%202023-05-08%20041713.png)

# %% [markdown]
# $$\chi ^2 = 18.93$$

# %%
import scipy.stats as stats
import numpy as np

# %%
observed_frequencies = np.array([32, 178, 290, 236, 64])
observed_frequencies
# Out:
# array([ 32, 178, 290, 236,  64])

# %%
expected_frequencies = np.array([50, 200, 300, 200, 50])
expected_frequencies
# Out:
# array([ 50, 200, 300, 200,  50])

# %%
alpha = 0.05

# %%
len(observed_frequencies)
# Out:
# 5

# %%
degrees_of_freedom = len(observed_frequencies) - 1
degrees_of_freedom
# Out:
# 4

# %%
chi_square_statistic = np.sum(((expected_frequencies - observed_frequencies)**2)/expected_frequencies)
chi_square_statistic
# Out:
# 19.633333333333333

# %%
p_value = 1 - stats.chi2.cdf(chi_square_statistic,degrees_of_freedom)
p_value
# Out:
# 0.0005898876209430304

# %%
critical_value = stats.chi2.ppf(1-alpha,degrees_of_freedom)
critical_value
# Out:
# 9.487729036781154

# %%
# Print the results
print(f"Chi-Square Statistic: {chi_square_statistic}")
print(f"Critical Value: {critical_value}")
print(f"P-value: {p_value}")
# Out:
# Chi-Square Statistic: 19.633333333333333
# Critical Value: 9.487729036781154
# P-value: 0.0005898876209430304

# %%
# Check if the null hypothesis is rejected
if p_value < alpha:
    print("Reject the null hypothesis. The observed distribution is significantly different from the expected binomial distribution.")
else:
    print("Fail to reject the null hypothesis. The observed distribution is consistent with the expected binomial distribution.")
# Out:
# Reject the null hypothesis. The observed distribution is significantly different from the expected binomial distribution.

# %% [markdown]
# since $\alpha=0.05$ and p-value = 0.00081122618.
#
# __so we reject the null hypothesis as p-value < 0.05. So it is not a binomial distribution with a probability 0.5__ but it can be a binomial distribution with different probability.

# %% [markdown]
# ### Test case : pclass (1,2,3) has equi probability of tickets in titanic i.e number of people in all 3 p-classes should be same

# %%
import pandas as pd
import numpy as np
from scipy.stats import chisquare

# Load the Titanic dataset
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
data = pd.read_csv(url)

data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ##### observed values : $f_o$

# %%
# Count passengers in each class
class_counts = data['Pclass'].value_counts().sort_index()
class_counts
# Out:
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %% [markdown]
# ##### expected values / theoretical:  $f_e$

# %%
# Calculate the expected counts assuming a uniform distribution
total_passengers = len(data)
expected_counts = total_passengers / 3
expected = [expected_counts] * 3
print("Expected Passenger Counts (assuming uniform distribution):\n", expected)
# Out:
# Expected Passenger Counts (assuming uniform distribution):
#  [297.0, 297.0, 297.0]

# %%
degrees_of_freedom = len(class_counts) - 1
degrees_of_freedom
# Out:
# 2

# %%
# Calculate the critical value from the chi-square distribution
critical_value = stats.chi2.ppf(1 - alpha, degrees_of_freedom)
critical_value
# Out:
# 5.991464547107979

# %% [markdown]
# ##### Perform the Chi-Square Goodness of Fit test :

# %%
chi2, p_value = stats.chisquare(f_obs = class_counts,f_exp = expected)

# Print the results
print("Chi-Square Statistic: {:.2f}".format(chi2))
print("critical_value",critical_value)
print("P-value: {:.4f}".format(p_value))
# Out:
# Chi-Square Statistic: 191.80
# critical_value 5.991464547107979
# P-value: 0.0000

# %%
# Check if the null hypothesis is rejected
if p_value < alpha:
    print("Reject the null hypothesis. The observed distribution is significantly different from the expected equal probability distribution.")
else:
    print("Fail to reject the null hypothesis. The observed distribution is consistent with the expected equal probability distribution.")
# Out:
# Reject the null hypothesis. The observed distribution is significantly different from the expected equal probability distribution.

# %% [markdown]
# ## 2. Test for Independence : 2 columns are independent

# %% [markdown]
# The Chi-Square test for independence, also known as the Chi-Square test for association, is a
# statistical test used to determine whether there is a significant association between two
# categorical variables in a sample. It helps to identify if the occurrence of one variable is
# dependent on the occurrence of the other variable, or if they are independent of each other.
#
#
# The test is based on comparing the observed frequencies in a contingency table (a table that
# displays the frequency distribution of the variables) with the frequencies that would be
# expected under the assumption of independence between the two variables.

# %% [markdown]
# ### NOTE : Here degree of freedom: df = (number of rows - 1) * (number of columns - 1)

# %% [markdown]
# ### Steps :
#
# 1. State the null hypothesis (H0) and alternative hypothesis (H1):
#     - H0: There is no association between the two categorical variables (they are
# independent).
#
#     - H1: There is an association between the two categorical variables (they are
# dependent).
#
#
# 2. Create a contingency table with the observed frequencies for each combination of the
# categories of the two variables.
#
#
#
# 3. Calculate the expected frequencies for each cell in the contingency table assuming that
# the null hypothesis is true (i.e., the variables are independent).
#
#
# 4. __Compute the Chi-Square test statistic:__
# $$\chi^2 = Σ \frac {(f_0 - f_e)^2}{f_e}$$
#
# - $f_o$__: is the observed frequency in each cell__
#
#
# -  $f_e$__: is the expected frequency.__
#
#
# 5. __Determine the degrees of freedom: df = (number of rows - 1) * (number of columns - 1)__
#
# ![Screenshot%202023-05-08%20044746.png](attachment:Screenshot%202023-05-08%20044746.png)
#
# 6. Obtain the critical value or p-value using the Chi-Square distribution table or a statistical
# software/calculator with the given degrees of freedom and significance level (commonly
# α = 0.05).
#
#
# 7. Compare the test statistic to the critical value or the p-value to the significance level to
# decide whether to reject or fail to reject the null hypothesis. If the test statistic is greater
# than the critical value, or if the p-value is less than the significance level, we reject the null
# hypothesis and conclude that there is a significant association between the two variables.

# %% [markdown]
# ### Assumptions
# 1. __Independence of observations:__ The observations in the sample should be independent of
# each other. This means that the occurrence of one observation should not affect the
# occurrence of another observation. In practice, this usually implies that the data should
# be collected using a simple random sampling method.
#
#
# 2. __Categorical variables:__ Both variables being tested must be categorical, either ordinal or
# nominal. The Chi-Square test for independence is not appropriate for continuous
# variables.
#
#
# 3. __Adequate sample size:__ The sample size should be large enough to ensure that the
# expected frequency for each cell in the contingency table is sufficient. A common rule of
# thumb is that the expected frequency for each cell should be at least 5. If some cells have
# expected frequencies less than 5, the test may not be valid, and other methods like
# Fisher's exact test may be more appropriate.
#
#
# 4. __Fixed marginal totals:__ The marginal totals (the row and column sums of the contingency
# table) should be fixed before the data is collected. This is because the Chi-Square test for
# independence assesses the association between the two variables under the assumption
# that the marginal totals are fixed and not influenced by the relationship between the
# variables.

# %% [markdown]
# ### Example 1
#
# A researcher wants to investigate if there is an association between the level of education
# (categorical variable) and the preference for a particular type of exercise (categorical variable)
# among a group of 150 individuals. The researcher collects data and creates the following
# contingency table
#
#
# ![Screenshot%202023-05-08%20045349.png](attachment:Screenshot%202023-05-08%20045349.png)

# %% [markdown]
# - ${H_o}$ : education and exercise are independent
#
#
#
# - $H_1$: education and exercise are not independent
#
#
#
# - $\alpha=0.05$
#
#
#
# - __Observed values $f_0$__:
#
#
# ![Screenshot%202023-05-08%20043328.png](attachment:Screenshot%202023-05-08%20043328.png)

# %% [markdown]
# ### NOTE : for expected value table we will multiply (probabilities of both the respective totals of column and row happening/ Grand total) * Grand total
#
# eg: for going to high school and doing yoga we will do high school total = 45 and yoga total = 40. The grand total = 150
#
# $$\frac{\text{going to high school}}{\text{grand total}} * \frac{\text{doing yoga}}{\text{grand total}}* \text{Grand total}$$
#
# $$\frac{45}{150}*\frac{40}{150}*150=12$$
#
# $$OR$$
#
#
# $$\frac{\text{going to high school * doing yoga}}{\text{grand total}} \Longrightarrow \frac{45 * 40}{150}=12$$

# %% [markdown]
# - __Expected values $f_e$__ :
#
# ![Screenshot%202023-05-08%20045941.png](attachment:Screenshot%202023-05-08%20045941.png)
#
#
# $$\chi^2=\frac{(15-12)^2}{12}+\frac{(20-19)^2}{19}.............=9.95(assumed)$$
#
#
# <br><br>
# - number of rows = 3
#
# - number of columns = 3
#
#
#
# - __degree of freedom__
#
#     - $(3-1)*(3-1) = 4$

# %%
import scipy.stats as stats

test_statistic = 9.95  # Chi-Square test statistic from the previous example
degrees_of_freedom = 4  # Degrees of freedom from the previous example

# Calculate the p-value using the chi2 survival function (sf)
p_value = stats.chi2.sf(test_statistic, degrees_of_freedom)

print("P-value:", p_value)
# Out:
# P-value: 0.04127840066324082

# %%
# Interpret the results
alpha = 0.05
if p_value < alpha:
    print("\nWe reject the null hypothesis. Hence, education and exercise are not independent. there is some association between them")
else:
    print("\nWe fail to reject the null hypothesis. Hence, education and exercise are independent")
# Out:
# We reject the null hypothesis. Hence, education and exercise are not independent. there is some association between them

# %% [markdown]
# ### Example 2 :
#
# #### voter polling data and perform a test of independence:

# %%
np.random.seed(10)

# %%
# Sample data randomly at fixed probabilities
voter_race = np.random.choice(a= ["asian","black","hispanic","other","white"],
                              p = [0.05, 0.15 ,0.25, 0.05, 0.5],
                              size=1000)

voter_race[:10]
# Out:
# array(['white', 'asian', 'white', 'white', 'other', 'hispanic', 'black',
#        'white', 'black', 'black'], dtype='<U8')

# %%
# Sample data randomly at fixed probabilities
voter_party = np.random.choice(a= ["democrat","independent","republican"],
                              p = [0.4, 0.2, 0.4],
                              size=1000)

voter_party[:10]
# Out:
# array(['democrat', 'republican', 'independent', 'republican', 'democrat',
#        'democrat', 'republican', 'democrat', 'independent', 'democrat'],
#       dtype='<U11')

# %%
voters = pd.DataFrame({"race":voter_race, 
                       "party":voter_party})

voters
# Out:
#          race        party
# 0       white     democrat
# 1       asian   republican
# 2       white  independent
# 3       white   republican
# 4       other     democrat
# ..        ...          ...
# 995     white   republican
# 996  hispanic  independent
# 997     black  independent
# 998     white   republican
# 999     black     democrat
#
# [1000 rows x 2 columns]

# %%
voter_tab = pd.crosstab(voters.race, voters.party, margins = True)

voter_tab.columns = ["democrat","independent","republican","row_totals"]

voter_tab.index = ["asian","black","hispanic","other","white","col_totals"]

voter_tab
# Out:
#             democrat  independent  republican  row_totals
# asian             21            7          32          60
# black             65           25          64         154
# hispanic         107           50          94         251
# other             15            8          15          38
# white            189           96         212         497
# col_totals       397          186         417        1000

# %%
grand_total = voter_tab['row_totals'][-1]
grand_total
# Out:
# 1000

# %%
observed = voter_tab.iloc[0:5,0:3]   # Get table without totals for later use
observed
# Out:
#           democrat  independent  republican
# asian           21            7          32
# black           65           25          64
# hispanic       107           50          94
# other           15            8          15
# white          189           96         212

# %% [markdown]
# #### use of np.outer :

# %% [markdown]
# `np.outer` is a function in the NumPy library that computes the outer product of two arrays. The outer product is a mathematical operation that takes two vectors (or arrays) and returns a matrix as the result. The resulting matrix has dimensions determined by the lengths of the input vectors.
#
# - `a` and `b` are input arrays or vectors.
#
#
# - The function returns a matrix that represents the outer product of `a` and `b`.
#
# The outer product is calculated as follows:
#
# 1. For each element `a[i]` in the first input array `a` and each element `b[j]` in the second input array `b`, the function computes the product `a[i] * b[j]`.
#
# 2. These products are then arranged in a matrix, where the element at position `(i, j)` in the resulting matrix corresponds to the product of `a[i] * b[j]`.
#
# The resulting matrix is often used in various mathematical and computational operations, including linear algebra, statistics, and machine learning.

# %%
import numpy as np

a = np.array([1, 2, 3])
print(a)
b = np.array([4, 5, 6])
print()
print(b)
print()

outer_product = np.outer(a, b)

print(outer_product)
# Out:
# [1 2 3]
#
# [4 5 6]
#
# [[ 4  5  6]
#  [ 8 10 12]
#  [12 15 18]]

# %%
expected =  np.outer(voter_tab["row_totals"][0:5],
                     voter_tab.loc["col_totals"][0:3]) / grand_total

expected = pd.DataFrame(expected)

expected.columns = ["democrat","independent","republican"]
expected.index = ["asian","black","hispanic","other","white"]

expected
# Out:
#           democrat  independent  republican
# asian       23.820       11.160      25.020
# black       61.138       28.644      64.218
# hispanic    99.647       46.686     104.667
# other       15.086        7.068      15.846
# white      197.309       92.442     207.249

# %%
chi_squared_stat = (((observed-expected)**2)/expected).sum().sum()

chi_squared_stat
# Out:
# 7.169321280162059

# %%
crit = stats.chi2.ppf(q = 0.95, # Find the critical value for 95% confidence*
                      df = 8)   # *

print("Critical value",crit)
# Out:
# Critical value 15.50731305586545

# %%
p_value = 1 - stats.chi2.cdf(x=chi_squared_stat,  # Find the p-value
                             df=8)
print("P value",p_value)
# Out:
# P value 0.518479392948842

# %% [markdown]
# Note: The degrees of freedom for a test of independence equals the product of the number of categories in each variable minus 1. In this case we have a 5x3 table so df = 4x2 = 8.

# %%
df = (5-1)*(3-1)
df
# Out:
# 8

# %% [markdown]
# ### doing the same using stats.chi2_contingency() :

# %% [markdown]
# #### As with the goodness-of-fit test, we can use scipy to conduct a test of independence quickly.
#
#
# > Use stats.chi2_contingency() function to conduct a test of independence automatically given a frequency table of observed counts:

# %%
chi_squared_stat,p_value,df,expected_values=stats.chi2_contingency(observed= observed)

# %%
print('chi_squared_statistics',chi_squared_stat)
print('p_value',p_value)
print('degree of freedom',df)
# Out:
# chi_squared_statistics 7.169321280162059
# p_value 0.518479392948842
# degree of freedom 8

# %%
print('expected_values : ')
expected_values_df = pd.DataFrame(expected_values)
expected_values_df.columns = ["democrat","independent","republican"]
expected_values_df.index = ["asian","black","hispanic","other","white"]
expected_values_df
# Out:
# expected_values :
#           democrat  independent  republican
# asian       23.820       11.160      25.020
# black       61.138       28.644      64.218
# hispanic    99.647       46.686     104.667
# other       15.086        7.068      15.846
# white      197.309       92.442     207.249

# %% [markdown]
# The output shows the chi-square statistic, the p-value and the degrees of freedom followed by the expected counts.
#
# As expected, given the high p-value, the test result does not detect a significant relationship between the variables.

# %% [markdown]
# ---

# %% [markdown]
# ### Test for Independence on titanic
#
# #### We will use the Chi-Square test for independence to see if the survival rate of passengers is independent of the passenger class.

# %%
# We will use the Chi-Square test for independence to see if the survival rate of passengers is independent of the passenger class.
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency

# Load the Titanic dataset
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
data = pd.read_csv(url)

data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
contingency_table = pd.crosstab(data['Survived'], data['Pclass'],margins=True)
contingency_table
# Out:
# Pclass      1    2    3  All
# Survived
# 0          80   97  372  549
# 1         136   87  119  342
# All       216  184  491  891

# %% [markdown]
# #### Perform the Chi-Square test :

# %%
chi2, p_value, dof, expected = chi2_contingency(contingency_table) # calulate expected values

# Print the results
print("\nChi-Square Statistic: {:.2f}".format(chi2))
print("P-value: {:.4f}".format(p_value))
print("Degrees of Freedom: {}".format(dof))
print()
print("Expected Frequencies: \n{}".format(expected))
# Out:
# Chi-Square Statistic: 102.89
# P-value: 0.0000
# Degrees of Freedom: 6
#
# Expected Frequencies:
# [[133.09090909 113.37373737 302.53535354 549.        ]
#  [ 82.90909091  70.62626263 188.46464646 342.        ]
#  [216.         184.         491.         891.        ]]

# %% [markdown]
# ##### Interpret the results :

# %%
alpha = 0.05
if p_value < alpha:
    print("\nWe reject the null hypothesis. There is a significant association between passenger class and survival rate.")
else:
    print("\nWe fail to reject the null hypothesis. There is no significant association between passenger class and survival rate.")
# Out:
# We reject the null hypothesis. There is a significant association between passenger class and survival rate.

# %% [markdown]
# ### Applications in Machine Learning

# %% [markdown]
# 1. __Feature selection:__ Chi-Square test can be used as a filter-based feature selection method to
# rank and select the most relevant categorical features in a dataset. By measuring the
# association between each categorical feature and the target variable, you can eliminate
# irrelevant or redundant features, which can help improve the performance and efficiency
# of machine learning models.
#
#
# 2. __Evaluation of classification models:__ For multi-class classification problems, the Chi-Square
# test can be used to compare the observed and expected class frequencies in the confusion
# matrix. This can help assess the goodness of fit of the classification model, indicating how
# well the model's predictions align with the actual class distributions.
#
#
# 3. __Analysing relationships between categorical features:__ In exploratory data analysis, the Chi-
# Square test for independence can be applied to identify relationships between pairs of categorical features. Understanding these relationships can help inform feature
# engineering and provide insights into the underlying structure of the data.
#
#
# 4. __Discretization of continuous variables:__ When converting continuous variables into
# categorical variables (binning), the Chi-Square test can be used to determine the optimal
# number of bins or intervals that best represent the relationship between the continuous
# variable and the target variable.
#
#
# 5. __Variable selection in decision trees:__ Some decision tree algorithms, such as the CHAID (Chi-
# squared Automatic Interaction Detection) algorithm, use the Chi-Square test to determine the most significant splitting variables at each node in the tree. This helps construct more
# effective and interpretable decision trees.

# %% [markdown]
# ___

# %% [markdown]
# # WEEK 21: ANNOVA

# %% [markdown]
# https://learnwith.campusx.in/s/courses/637339afe4b0615a1bbed390/take

# %% [markdown]
# ### F - Distribution

# %% [markdown]
# 1. __Continuous probability distribution:__ The F-distribution is a continuous
# probability distribution used in statistical hypothesis testing and
# analysis of variance (ANOVA).
#
#
# 2. __Fisher-Snedecor distribution:__ It is also known as the Fisher-Snedecor
# distribution, named after Ronald Fisher and George Snedecor, two
# prominent statisticians.
#
#
# 3. __Degrees of freedom:__ The F-distribution is defined by two parameters -
# the ___degrees of freedom for the numerator (df1) and the degrees of
# freedom for the denominator (df2).___
#
#
# 4. __Positively skewed and bounded:__ The shape of the F-distribution is
# positively skewed, with its left bound at zero. The distribution's shape
# depends on the values of the degrees of freedom. __cannot have negative values.__
#
#
# 5. __Testing equality of variances:__ The F-distribution is commonly used to
# test hypotheses about the __equality of two variances__ in different
# samples or populations.
#
#
# 6. __Comparing statistical models:__ The F-distribution is also used to compare
# the fit of different statistical models, particularly in the context of
# ANOVA.
#
#
# 7. __F-statistic:__ The F-statistic is calculated by dividing the ratio of two
# sample variances or mean squares from an ANOVA table. This value is
# then compared to critical values from the F-distribution to determine
# statistical significance.
#
#
# 8. __Applications:__ The F-distribution is widely used in various fields of
# research, including psychology, education, economics, and the natural
# and social sciences, for hypothesis testing and model comparison.

# %% [markdown]
# __F-distribution = chi-square distribution divided by degree of freedom__
#
#
# - degree of freedom 1 df1 from chi-sqaure in numerator
# - degree of freedom 2 df2 from chi-sqaure in denominator

# %% [markdown]
# ![Screenshot%202023-05-08%20212831.png](attachment:Screenshot%202023-05-08%20212831.png)

# %% [markdown]
# ![Screenshot%202023-08-31%20032521.png](attachment:Screenshot%202023-08-31%20032521.png)

# %% [markdown]
# ## Anova Test - One way F-Test

# %% [markdown]
# - The t-test works well when dealing with two groups, but sometimes we want to compare more than two groups at the same time.<br></br>
#     - For example, if we wanted to test whether petal_width age differs based on some categorical variable like species, we have to compare the means of each level or group the variable
#
#
# - It tell whether two or more groups are similar or not based on their mean similarity and f-score.<br></br>
#     - Example : there are 3 different category of iris flowers and their petal width and need to check whether all 3 group are similar or not

# %% [markdown]
# ![Screenshot%202023-05-08%20052618.png](attachment:Screenshot%202023-05-08%20052618.png)

# %% [markdown]
# - 1 categorical column with  2 categories $\longrightarrow$ t-test
#
#
# - 1 categorical column with more than 2 categories $\longrightarrow$ ANNOVA

# %% [markdown]
# ### why do we need anova when we already have t-test?

# %% [markdown]
# ANOVA (Analysis of Variance) and t-tests are both statistical methods used to compare means of groups or datasets, but they serve different purposes and are applicable in different situations.
#
#
#
# Here's why we need ANOVA even when t-tests are available:
#
# 1. **Comparison of Multiple Groups:**<br></br>
#    - ANOVA is designed to compare means across __three or more groups or treatments.__ It allows you to test whether there are significant differences among the means of multiple groups simultaneously.<br></br>
#    - T-tests, on the other hand, are designed for comparing the __means of two groups.__ If you have more than two groups, conducting multiple t-tests for pairwise comparisons can lead to an increased risk of Type I errors (false positives).
#
#
#
# 2. **Type I Error Control:**
#    - Conducting multiple t-tests without correction increases the overall chance of making a Type I error (incorrectly rejecting a null hypothesis when it's true). ANOVA provides a way to control the overall Type I error rate, which is important in maintaining the reliability of statistical tests.

# %% [markdown]
# ### One way ANOVA test

# %% [markdown]
# - One-way ANOVA (Analysis of Variance) is a statistical method used to __compare the means of
# three or more independent groups__ to determine if there are any significant differences
# between them. It is an extension of the t-test, which is used for comparing the means of two
# independent groups.
#
#
# - The term "one-way" refers to the fact that there is __only one independent
# variable (factor) with multiple levels (groups)__ in this analysis. eg : employee column with  analyst, senior analyst and manager category
#
#
#
# - The primary purpose of one-way ANOVA is to test the ___null hypothesis that all the group means
# are equal.___ The __alternative hypothesis__ is that at least one group mean is significantly different
# from the others.

# %% [markdown]
# ## Steps :

# %% [markdown]
# ### 1. Define the null and alternative hypotheses.

# %% [markdown]
# - $H_0 :$ mean of all the groups are equal
#
#
# - $H_1 :$ mean of atleast 1 group is significantly different

# %% [markdown]
# ![Screenshot%202023-08-31%20033456.png](attachment:Screenshot%202023-08-31%20033456.png)

# %% [markdown]
# ### 2. Calculate the overall mean (grand mean) of all the groups combined and mean of all the groups individually.

# %% [markdown]
# $$\text{grand mean = mean of all values combined}\;(\bar{\bar x})\;=\;6$$

# %% [markdown]
# ![Screenshot%202023-08-31%20034229.png](attachment:Screenshot%202023-08-31%20034229.png)

# %% [markdown]
# ![Screenshot%202023-08-31%20035524.png](attachment:Screenshot%202023-08-31%20035524.png)

# %% [markdown]
# ### 3. Calculate the "sum of square total",  "between-group" and "within-group" sum of squares (SS).

# %% [markdown]
# ![Screenshot%202023-05-08%20234940.png](attachment:Screenshot%202023-05-08%20234940.png)

# %% [markdown]
# #### a. calculating SST (Sum of squares total) :

# %% [markdown]
# > __This gives overall variance of the data. distance between each point with the Grand Mean.__

# %% [markdown]
# $$\sum (Grand\;total\;mean\; - \;each\;element)^2$$
#
# - also called as variance of entire dataset
#
# ![Screenshot%202023-08-31%20035846.png](attachment:Screenshot%202023-08-31%20035846.png)

# %% [markdown]
# ##### degree of freedom for SST = n -1 = 9 - 1 = 8 (not required to be calculate, not used anywhere)

# %% [markdown]
# #### b. calculating SSW (Sum of squares within samples or categories) :
#
#
# $$\sum (mean\;of\;each\;group - elements\;of\;that\;group)^2$$
#
# > __Internal variance of each group__

# %% [markdown]
# ![Screenshot%202023-08-31%20035524.png](attachment:Screenshot%202023-08-31%20035524.png)

# %% [markdown]
# ![Screenshot%202023-08-31%20040448.png](attachment:Screenshot%202023-08-31%20040448.png)

# %% [markdown]
# ##### degree of freedom of each group = ( n - k )

# %% [markdown]
# ![Screenshot%202023-08-31%20040940.png](attachment:Screenshot%202023-08-31%20040940.png)

# %% [markdown]
# total degree of freedom = n - k = 9 - 3 = 6

# %% [markdown]
# #### c. calculating SSB (Sum of squared between samples or categories) and degree of freedom :
#
#
# $$\sum (\text{number of sample in that group}*\;(Grand\;mean\;-\;mean\;of\;each\; group)^2)$$

# %% [markdown]
# > __variance between grand mean and each group mean__

# %% [markdown]
# ![Screenshot%202023-08-31%20042057.png](attachment:Screenshot%202023-08-31%20042057.png)

# %% [markdown]
# ##### - degree of freedom = (k - 1) = 3 - 1 = 2

# %% [markdown]
# #### finally :
#
# ![Screenshot%202023-08-31%20042534.png](attachment:Screenshot%202023-08-31%20042534.png)

# %% [markdown]
# ## Rule : SST = SSW + SSB (for both values and df)

# %% [markdown]
# ### 4. F-ratio :
#
# #### Calculate the "between-group" and "within-group" mean squares (MS) by dividing their respective sum of squares by their degrees of freedom.

# %% [markdown]
# ![Screenshot%202023-08-31%20043217.png](attachment:Screenshot%202023-08-31%20043217.png)

# %% [markdown]
# $$a.\;\frac{SS_{between}}{df_{SSB}} = \frac{24}{2}=12$$
#
#
#
# $$b.\;\frac{SS_{within}}{df_{SSW}} = \frac{52}{6}$$

# %% [markdown]
# ### 5. Calculate the F-statistic by dividing the "between-group" mean square by the "within- group" mean square.

# %% [markdown]
# $$\text{f-statistics}\Longrightarrow\frac{SS_{between}}{df_{SSB}} * \frac{df_{SSW}}{SS_{within}}$$
# <br></br>
#
#
# $$F=\frac{24}{2} * \frac{6}{52} = \frac{18}{13} \approx 1.4 $$
# <br></br>
# $$\text{So, f-statistics} = 1.4$$

# %% [markdown]
# ### 6. Calculate the p-value associated with the calculated F-statistic using the F-distribution and the appropriate degrees of freedom.
#
#
# - The p-value represents the probability of obtaining
# an F-statistic as extreme or more extreme than the calculated value, assuming the null
# hypothesis is true.
#
#
# - Choose a significance level (alpha), typically 0.05.
#
#
# - Compare the calculated p-value with the chosen significance level (alpha).
#
#     - If the p-value is less than or equal to alpha, reject the null hypothesis in favour of the alternative
# hypothesis, concluding that there is a significant difference between at least one pair of group
# means.
#     - If the p-value is greater than alpha, fail to reject the null hypothesis, concluding that there is not
# enough evidence to suggest a significant difference between the group means.

# %% [markdown]
# #### calculating p-value for given f-statistic:

# %%
import scipy.stats as stats

f_statistic = 1.4  # The F-statistic value you've calculated
df1 = 2            # Degrees of freedom for the numerator (between groups)
df2 = 6           # Degrees of freedom for the denominator (within groups)

p_value = stats.f.sf(f_statistic, df1, df2)
print("P-value:", p_value)
# Out:
# P-value: 0.31696093163035305

# %% [markdown]
# ### Conclusion : since p-value 0.31 > significance level ($\alpha$) 0.05 . So NULL Hypothesis can't be rejected
#
#
# $$Hence\; \mu_{A}=\mu_{B}=\mu_C$$

# %% [markdown]
# - It's important to note that one-way ANOVA only determines if there is a significant difference
# between the group means
#
#
# - it does not identify which specific groups have significant differences.
#
#
# - To determine which pairs of groups are significantly different, post-hoc tests, such
# as Tukey's HSD or Bonferroni, are conducted after a significant ANOVA result.

# %% [markdown]
# ### Points to remember :
#
#
# - __F-statistics calculated will follow f-distribution as SSB and SSW will follow chi-square distribution.__
#
#
#
# - __F-statisctics will always between 0 to +ve, it can never be -ve.__
#
#
# - __F$\uparrow$ when SSB $\uparrow$ SSW $\downarrow$ ie. sample mean (SSB) will be very far from parent population mean. Mean of all 3 will never be same. Hence p-value will be small.__
#
#
# - __F$\downarrow$ when SSB $\downarrow$ SSW $\uparrow$ i.e graph will be flatter. All child population will be very close to each other and to the parent population. Mean will be same to each other.__
#
#
#
# -  __we are not proving that  $\mu_A=\mu_B=\mu_C$ which is the null hypothesis, insted we are proving that $\mu_A, \mu_B, \mu_C$ are not different population but are part  of the same larger population. Hence population mean will be same for all.__
#
#
#
# -  __$\mu_A, \mu_B, \mu_C$ are mean of 3 distributions from the same population. The population not necesaarily will be normal distribution__

# %% [markdown]
# #### Intuition of SSB $\downarrow$
#
# - All child population will be very close to each other and to the parent population. Mean will be same to each other.
#
# ![Screenshot%202023-08-31%20052758.png](attachment:Screenshot%202023-08-31%20052758.png)

# %% [markdown]
# ### Assumptions
# 1. __Independence :__ The observations within and between groups should be independent of
# each other. This means that the outcome of one observation should not influence the
# outcome of another. Independence is typically achieved through random sampling or
# random assignment of subjects to groups.
#
#
# 2. __Normality :__ The data within each group should be approximately normally distributed.
# While one-way ANOVA is considered to be robust to moderate violations of normality,
# severe deviations may affect the accuracy of the test results. If normality is in doubt, non-
# parametric alternatives like the Shapiro-wilk test can be considered.
#
#
#
# 3. __Homogeneity of variances :__ The variances of the populations from which the samples are
# drawn should be equal, or at least approximately so. This assumption is known as
# homoscedasticity. If the variances are substantially different, the accuracy of the test
# results may be compromised. Levene's test or Bartlett's test can be used to assess the
# homogeneity of variances. If this assumption is violated, alternative tests such as Welch's
# ANOVA can be used.

# %% [markdown]
# ## Example 1: using sm.stats.anova_lm

# %% [markdown]
# You can perform a one-way ANOVA in Python using the `anova_lm` function from the StatsModels library. Here's an example of how to do it:

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Sample data for plant growth (heights in cm)
data = {'PlantHeight': [30, 32, 28, 29, 31, 27, 25, 26, 30, 28, 35, 34, 36, 33, 37],
        'PlantType': ['A', 'A', 'A', 'A', 'A', 'B', 'B', 'B', 'B', 'B', 'C', 'C', 'C', 'C', 'C']}

# Create a DataFrame
df = pd.DataFrame(data)

# Fit the one-way ANOVA model
model = ols('PlantHeight ~ PlantType', data=df).fit()

# Perform ANOVA and print the results
anova_table = sm.stats.anova_lm(model, typ=2)
print(anova_table)
# Out:
#                sum_sq    df         F    PR(>F)
# PlantType  156.133333   2.0  26.91954  0.000037
# Residual    34.800000  12.0       NaN       NaN

# %% [markdown]
# In this code:
#
# 1. We create a DataFrame `df` containing the plant height data and the corresponding plant types (A, B, and C).
#
# 2. We use the `ols` function to specify a formula for the one-way ANOVA model. Here, we model `PlantHeight` as a function of `PlantType`.
#
# 3. We fit the model using `.fit()`.
#
# 4. We use `sm.stats.anova_lm` to perform the ANOVA and create an ANOVA table.
#
# 5. The `typ=2` argument specifies the type of sum of squares to use in the ANOVA table (Type 2).
#
# 6. We print the ANOVA table, which includes the F-statistic, p-value, and other relevant statistics.
#
# Running this code will perform a one-way ANOVA analysis on the plant growth data and provide you with the ANOVA table, summarizing the results of the analysis.

# %% [markdown]
# ## Example on Titanic dataset : using One-way Anova

# %% [markdown]
# ![Screenshot%202023-08-31%20053553.png](attachment:Screenshot%202023-08-31%20053553.png)

# %% [markdown]
# $$\text{under Age all 3 classes: P1, P2, P3}$$

# %%
import pandas as pd
import numpy as np
from scipy.stats import chisquare

# %%
# Load the Titanic dataset
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url).dropna(subset=['Age'])

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[df['Pclass'] == 3]['Age'].mean()
# Out:
# 25.14061971830986

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %% [markdown]
# ### using anova_lm :

# %%
model = ols('Age ~ Pclass', data = df).fit() # age is numerical and Pclass is categorical
                
anova_result = sm.stats.anova_lm(model, typ=2)
print (anova_result)
# Out:
#                  sum_sq     df           F        PR(>F)
# Pclass     20511.429755    1.0  112.386893  1.756699e-24
# Residual  129945.206190  712.0         NaN           NaN

# %% [markdown]
# - ANOVA provides an overall assessment of group differences, which is useful for hypothesis testing.
#
#
#
# - If ANOVA indicates significant differences among groups, you can follow up with post-hoc tests or pairwise t-tests to identify which specific group differences are significant.

# %% [markdown]
# #### OR USING stats.f_oneway

# %%
# Load the Titanic dataset
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
titanic_data = pd.read_csv(url).dropna(subset=['Age'])

titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Step 3: Prepare the data for the ANOVA
# Filter out missing values in the 'Age' column
titanic_data = titanic_data.dropna(subset=['Age'])

# Create separate data frames for each passenger class (Pclass)
pclass_1 = titanic_data[titanic_data['Pclass'] == 1]['Age']
pclass_2 = titanic_data[titanic_data['Pclass'] == 2]['Age']
pclass_3 = titanic_data[titanic_data['Pclass'] == 3]['Age']

# %%
# Step 4: Perform the ANOVA
f_statistic, p_value = stats.f_oneway(pclass_1, pclass_2, pclass_3)

# %%
# Step 5: Interpret the results
alpha = 0.05  # Set the significance level

# %%
print(f"F-statistic: {f_statistic:.4f}")
print(f"P-value: {p_value:.9f}")
# Out:
# F-statistic: 57.4435
# P-value: 0.000000000

# %%
if p_value < alpha:
    print("Reject the null hypothesis.")
    print("There are significant differences in the mean ages between passenger classes.")
else:
    print("Fail to reject the null hypothesis.")
    print("There is no significant difference in the mean ages between passenger classes.")
# Out:
# Reject the null hypothesis.
# There are significant differences in the mean ages between passenger classes.

# %% [markdown]
# ## When we reject the null hypothesis i.e. mean of groups are not equal :

# %% [markdown]
# ### Post-hoc Test

# %% [markdown]
# __if we reject the Null hypothesis, then we need to find out which groups means was different from other 2 using post hoc__
#
#  - Post hoc tests, also known as post hoc pairwise comparisons or multiple comparison tests, are
# used in the context of ANOVA when the overall test indicates a significant difference among
# the group means.
#
#
#
# - These tests are performed after the initial one-way ANOVA to determine
# which specific groups or pairs of groups have significantly different means.
#
#
#
# - The main purpose of post hoc tests is to control the family-wise error rate (FWER) and adjust
# the significance level for multiple comparisons to avoid inflated Type I errors.
#
#
#
# - There are
# several post hoc tests available, each with different characteristics and assumptions.
#
#
#
# Some common post hoc tests include:

# %% [markdown]
# ### 1. Bonferroni correction :
#
# This method adjusts the significance level (α) by dividing it by the
# number of comparisons being made. It is a conservative method that can be applied when
# making multiple comparisons, but it may have lower statistical power when a large
# number of comparisons are involved.

# %% [markdown]
# ___working : Taking 2 groups at a time and making a pair. The group that is the farthest will make the p-value down in it's pair. whichever 2 pair's values are low. The common one is the group which is the farthest.___

# %%
import scipy.stats as stats

# %% [markdown]
# #### applying independent 2 sample t-test: stats.ttest_ind

# %%
for class1,class2 in [(1,2),(2,3),(3,1)]: 
    print(class1,class2)
    print(stats.ttest_ind(df[df['Pclass'] == class1]['Age'], df[df['Pclass'] == class2]['Age']))
# Out:
# 1 2
# Ttest_indResult(statistic=5.485187676773201, pvalue=7.835568991415144e-08)
# 2 3
# Ttest_indResult(statistic=3.927800191020872, pvalue=9.715078600777852e-05)
# 3 1
# Ttest_indResult(statistic=-10.849122601201033, pvalue=6.134470007830625e-25)

# %% [markdown]
# ##### culprit here is 1 which is decreasing the p-value of the pair

# %%
print("average age of p-class 1 = ",df[df['Pclass']==1]['Age'].mean())
print("average age of p-class 2 = ",df[df['Pclass']==2]['Age'].mean())
print("average age of p-class 3 = ",df[df['Pclass']==3]['Age'].mean())
# Out:
# average age of p-class 1 =  38.233440860215055
# average age of p-class 2 =  29.87763005780347
# average age of p-class 3 =  25.14061971830986

# %% [markdown]
# ##### average age of p-class1 is the farthest hence decreasing the p-value of the pairs.

# %% [markdown]
# #### test is not very reliable as significance level is 5 % i.e $\alpha=0.05$ Leading to Type-I error . Instead we will use $\frac{0.05}{\text{no of trails or no. of pairs}}$ so final result =

# %%
print("new_pvalue class1=",7.835568991415144e-08/3)
print("new_pvalue class2=",9.715078600777852e-05/3)
print("new_pvalue class3=",6.134470007830625e-25/3)
# Out:
# new_pvalue class1= 2.6118563304717148e-08
# new_pvalue class2= 3.238359533592617e-05
# new_pvalue class3= 2.0448233359435419e-25

# %% [markdown]
# ### 2. Tukey's HSD (Honestly Significant Difference) test :
#
#
# This test controls the FWER and is used
# when the sample sizes are equal and the variances are assumed to be equal across the
# groups. It is one of the most commonly used post hoc tests.

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

# %%
tukey = pairwise_tukeyhsd(endog=df['Age'], groups=df['Pclass'], alpha=0.05) # age is numerical and p-calss is categorical

tukey.plot_simultaneous()

plt.vlines(x=49.57,ymin=-0.5,ymax=4.5, color="red")

print("it gives mean diff between each group:")

pd.DataFrame(tukey.summary())
# Out:
# it gives mean diff between each group:
#         0       1         2       3         4         5       6
# 0  group1  group2  meandiff   p-adj     lower     upper  reject
# 1       1       2   -8.3558     0.0  -11.7041   -5.0075    True
# 2       1       3  -13.0928    -0.0  -15.9622  -10.2234    True
# 3       2       3    -4.737  0.0005   -7.6763   -1.7977    True

# %% [markdown]
# ### Why t-test is not used for more than 3 categories? - interview question

# %% [markdown]
# When performing post hoc tests, it is essential to choose a test that aligns with the
# assumptions of your data (e.g., equal variances, equal sample sizes) and provides an
# appropriate balance between controlling Type I errors and maintaining statistical power.

# %% [markdown]
# 1. __Increased Type I error :__ When you perform multiple comparisons using individual t-tests,
# the probability of making a Type I error (false positive) increases. The more tests you
# perform, the higher the chance that you will incorrectly reject the null hypothesis in at least
# one of the tests, even if the null hypothesis is true for all groups.
#
#
# 2. __Difficulty in interpreting results :__ When comparing multiple groups using multiple t-tests,
# the interpretation of the results can become complicated. For example, if you have 4
# groups and you perform 6 pairwise t-tests, it can be challenging to interpret and summarize
# the overall pattern of differences among the groups.
#
#
# 3. __Inefficiency :__ Using multiple t-tests is less efficient than using a single test that accounts for
# all groups, such as one-way ANOVA. One-way ANOVA uses the information from all the
# groups simultaneously to estimate the variability within and between the groups, which
# can lead to more accurate conclusions.

# %% [markdown]
# ### Applications in Machine Learning:

# %% [markdown]
# 1. __Hyperparameter tuning :__ When selecting the best hyperparameters for a machine learning
# model, one-way ANOVA can be used to compare the performance of models with different
# hyperparameter settings. By treating each hyperparameter setting as a group, you can
# perform one-way ANOVA to determine if there are any significant differences in
# performance across the various settings.
#
#
# 2. __Feature selection :__ One-way ANOVA can be used as a univariate feature selection method to
# identify features that are significantly associated with the target variable, especially when
# the target variable is categorical with more than two levels. In this context, the one-way
# ANOVA is performed for each feature, and features with low p-values are considered to be
# more relevant for prediction.
#
#
# 3. __Algorithm comparison :__ When comparing the performance of different machine learning
# algorithms, one-way ANOVA can be used to determine if there are any significant
# differences in their performance metrics (e.g., accuracy, F1 score, etc.) across multiple runs
# or cross-validation folds. This can help you decide which algorithm is the most suitable for a
# specific problem.
#
#
# 4. __Model stability assessment :__ One-way ANOVA can be used to assess the stability of a
# machine learning model by comparing its performance across different random seeds or
# initializations. If the model's performance varies significantly between different
# initializations, it may indicate that the model is unstable or highly sensitive to the choice of
# initial conditions.

# %% [markdown]
# ### Difference between ANOVA and f-test:

# %% [markdown]
# - ANOVA is a specific application of the F-test that focuses on __comparing group means,__ while the F-test is a more general test used for __comparing variances or standard deviations.__
#
#
# - ANOVA is used when you want to determine if there are statistically significant __differences in means__ among multiple groups, while the F-test can be applied in various situations where you need to __compare variances.__

# %% [markdown]
# ### Difference between F-statistics, F-test and F-distribution:

# %% [markdown]
# 1. **F-Statistics (F-statistic):**
#    - **Definition:** The F-statistic is a value calculated in statistical analysis, often used in ANOVA and regression analysis. It represents the ratio of two variances and helps assess the significance of differences or relationships.
#    - **Example:** In an ANOVA test comparing the test scores of three different teaching methods, the F-statistic quantifies the variation in test scores between the methods relative to the variation within each method.
#
#
#
# 2. **F-Test:**
#    - **Definition:** The F-test is a statistical hypothesis test that uses the F-statistic to determine whether the variances of two or more groups or populations are equal. It assesses if there are significant differences in variability.
#    - **Example:** In quality control, an F-test can be used to compare the variances of two different manufacturing processes to determine if one process has significantly higher variability than the other.
#
#
#
# 3. **F-Distribution:**
#    - **Definition:** The F-distribution is a probability distribution used in statistical hypothesis testing. It is the distribution of the F-statistic when comparing variances or testing the significance of regression models.
#    - **Example:** When conducting an F-test to compare the variances of two datasets, the F-distribution provides critical values to determine whether the test statistic is statistically significant.
#
#
#
# ___In summary, the F-statistic is a numerical value calculated in statistical analysis, the F-test is a hypothesis test that uses the F-statistic to assess differences in variances or model significance, and the F-distribution is the probability distribution associated with the F-statistic. These concepts are interrelated and commonly used in statistical analysis.___

# %% [markdown]
# ### Difference between one way anova and two way anova:

# %% [markdown]
# Two-way ANOVA (Analysis of Variance) and one-way ANOVA are both statistical techniques used to analyze and compare groups or datasets. However, they differ in terms of the number of factors or independent variables they consider and the types of questions they address:
#
# 1. **One-Way ANOVA:**
#    - One-way ANOVA is used when you have one categorical independent variable (factor) with more than two levels or groups, and you want to compare the means of these groups to determine if there are statistically significant differences among them.
#    - One-way ANOVA answers questions such as whether there are significant differences in test scores among students taught by different teachers or whether there are differences in the performance of three different drug treatments on a medical condition.
#    - The factor in one-way ANOVA represents the categories or groups you are comparing, and you test whether their means are significantly different.
#
#
#
# 2. **Two-Way ANOVA:**
#    - Two-way ANOVA, on the other hand, is used when you have two independent categorical variables (factors) and want to examine how they interact with each other and how they independently influence a dependent variable.
#    - Two-way ANOVA is appropriate for situations where you want to answer questions like whether there are significant differences in test scores due to the teacher's teaching method (factor 1), the students' background (factor 2), and whether there is an interaction effect between the two factors.
#    - In two-way ANOVA, you can assess the main effects of each factor (independently) and the interaction effect between the two factors.

# %% [markdown]
# Key differences between one-way ANOVA and two-way ANOVA:
#
# - **Number of Factors:**
#    - One-way ANOVA involves one categorical factor.
#    - Two-way ANOVA involves two categorical factors.
#
# - **Main Effects and Interaction:**
#    - One-way ANOVA tests for differences among the groups defined by a single factor.
#    - Two-way ANOVA tests for differences due to two factors and assesses both main effects (independent influences of each factor) and interaction effects (combined influence of the factors).
#
# - **Research Questions:**
#    - One-way ANOVA answers questions about differences among groups defined by one factor.
#    - Two-way ANOVA answers questions about how two factors independently and together influence a dependent variable.
#
# In summary, the key distinction between one-way and two-way ANOVA is the number of independent categorical factors being considered and the types of research questions they address. One-way ANOVA is used for comparing groups defined by a single factor, while two-way ANOVA is used for examining the effects of two factors and their interactions on a dependent variable.

# %% [markdown]
# ## Two-way ANOVA:

# %% [markdown]
# https://www.youtube.com/watch?v=cNIIn9bConY&ab_channel=statisticsfun

# %% [markdown]
# - Two-way ANOVA (Analysis of Variance) is a statistical technique used to analyze the influence of __two categorical independent variables (factors) on a continuous dependent variable.__
#
#
# - It extends the concept of one-way ANOVA, which assesses the impact of a single factor. Two-way ANOVA is more complex but provides a more comprehensive analysis by considering interactions between the two factors.
#
#
#
# Let's break down two-way ANOVA in detail, including its formula, calculations, and differences from one-way ANOVA :
#
# **Formula of Two-Way ANOVA:**
#
# The general formula for a two-way ANOVA model with two factors (A and B) is as follows:
#
# $$Y_{ij} = \mu + A_i + B_j + (A \cdot B)_{ij} + \varepsilon_{ij}$$
#
# - $Y_{ij}$ is the observed value for the dependent variable.
# - $\mu$ is the overall mean.
# - $A_i$ represents the effect of factor A for level $i$.
# - $B_j$ represents the effect of factor B for level $j$.
# - $(A \cdot B)_{ij}$ represents the interaction effect between factor A at level $i$ and factor B at level $j$.
# - $\varepsilon_{ij}$ is the random error term.

# %% [markdown]
# **Steps for Two-Way ANOVA:**
#
# 1. **Data Preparation:**
#    - Collect and organize your data into a table or dataframe with columns for the dependent variable and two categorical independent variables (factors A and B).
#
# 2. **Hypotheses:**
#    - Formulate null and alternative hypotheses:
#      - Null Hypothesis (H0): There are no significant main effects of factors A and B, and there is no significant interaction effect between them.
#      - Alternative Hypothesis (Ha): At least one main effect or interaction effect is significant.
#
# 3. **Calculate Group Means:**
#    - Calculate the means of the dependent variable for each combination of factor levels (A and B).
#
# 4. **Calculate Sum of Squares (SS):**
#    - Calculate the sum of squares for each factor (SSA for factor A, SSB for factor B) and the interaction effect (SSAB).
#    - SS = $\sum (Y_{ij} - \mu)^2$
#    - SSA, SSB, and SSAB represent the variability explained by each factor.
#
# 5. **Degrees of Freedom (df):**
#    - Calculate the degrees of freedom for each source of variation (dfA, dfB, dfAB) based on the number of levels in each factor.
#
# 6. **Mean Squares (MS):**
#    - Calculate mean squares for each source of variation by dividing SS by its respective degrees of freedom.
#
# 7. **F-Statistic:**
#    - Calculate the F-statistic for each factor and interaction using the mean squares:
#      - $F_A = \frac{MSA}{MSE}$
#      - $F_B = \frac{MSB}{MSE}$
#      - $F_{AB} = \frac{MSAB}{MSE}$
#    - Where MSE is the mean square of error (residuals).
#
# 8. **P-Value:**
#    - Calculate the p-values associated with the F-statistics using the F-distribution.
#
# 9. **Hypothesis Testing:**
#    - Conduct hypothesis tests for each factor and interaction:
#      - For factor A: Compare $F_A$ to the critical value or calculate the p-value.
#      - For factor B: Compare $F_B$ to the critical value or calculate the p-value.
#      - For interaction: Compare $F_{AB}$ to the critical value or calculate the p-value.
#
# 10. **Interpretation:**
#     - If any of the F-tests for factors A, B, or the interaction are statistically significant (p < alpha), you reject the null hypothesis.
#     - Determine the significance of the main effects and interaction effects.

# %% [markdown]
# **Differences from One-Way ANOVA:**
#
# 1. **Number of Factors:**
#    - One-way ANOVA has one categorical factor, while two-way ANOVA has two factors.
#
# 2. **Interaction Effect:**
#    - One-way ANOVA assesses only the main effect of the single factor.
#    - Two-way ANOVA assesses the main effects of two factors and the interaction effect between them.
#
# **Example:**
#
# Consider an example in which you are analyzing the impact of two factors, "Teaching Method" (A) and "Student Background" (B), on students' test scores. In one-way ANOVA, you'd only analyze the effect of one of these factors, such as "Teaching Method." In two-way ANOVA, you simultaneously assess how both factors, "Teaching Method" and "Student Background," influence test scores and whether there's an interaction between them. This provides a more comprehensive understanding of the factors influencing test scores.

# %% [markdown]
# - In this example, we'll analyze the impact of two factors, "Teaching Method" and "Student Background," on students' test scores. We'll use a hypothetical dataset and perform a two-way ANOVA to understand how these factors affect test scores.
#
# **Step 1: Data Preparation**
#
# Imagine we have a dataset that looks like this:
#
# | Student | Teaching Method | Student Background | Test Score |
# |---------|-----------------|--------------------|------------|
# | 1       | Method A        | Low                | 85         |
# | 2       | Method B        | High               | 92         |
# | 3       | Method A        | Low                | 78         |
# | 4       | Method C        | Medium             | 88         |
# | 5       | Method B        | High               | 94         |
# | 6       | Method C        | Medium             | 89         |
#
# We have three variables: "Teaching Method," "Student Background," and "Test Score."
#
# **Step 2: Hypotheses**
#
# We want to test the following hypotheses:
#
# - Null Hypothesis (H0):
#   - There are no significant main effects of Teaching Method or Student Background on test scores.
#   - There is no significant interaction effect between Teaching Method and Student Background.
#
# - Alternative Hypothesis (Ha):
#   - At least one main effect (Teaching Method or Student Background) or the interaction effect is significant.
#
# **Step 3: Calculate Group Means**
#
# Calculate the means of the test scores for each combination of Teaching Method and Student Background:
#
# | Teaching Method | Student Background | Mean Test Score |
# |-----------------|--------------------|-----------------|
# | Method A        | Low                | 81.5            |
# | Method A        | Medium             | 85.5            |
# | Method A        | High               | 88.0            |
# | Method B        | Low                | 84.5            |
# | Method B        | Medium             | 85.5            |
# | Method B        | High               | 93.0            |
# | Method C        | Low                | 86.5            |
# | Method C        | Medium             | 89.0            |
# | Method C        | High               | 92.0            |
#
# **Step 4: Calculate Sum of Squares (SS)**
#
# Calculate the sum of squares for Teaching Method (SS_Method), Student Background (SS_Background), and the interaction (SS_Interaction).
#
# - SS_Method: Sum of squares for Teaching Method
# - SS_Background: Sum of squares for Student Background
# - SS_Interaction: Sum of squares for the interaction
#
# These calculations involve comparing the variation within each group to the variation between groups for each factor and their interaction.
#
# **Step 5: Degrees of Freedom (df)**
#
# Calculate the degrees of freedom for each source of variation (df_Method, df_Background, df_Interaction) based on the number of levels in each factor.
#
# - df_Method: Degrees of freedom for Teaching Method
# - df_Background: Degrees of freedom for Student Background
# - df_Interaction: Degrees of freedom for the interaction
#
# **Step 6: Mean Squares (MS)**
#
# Calculate mean squares for each source of variation (MS_Method, MS_Background, MS_Interaction) by dividing the sum of squares by its respective degrees of freedom.
#
# **Step 7: F-Statistic**
#
# Calculate the F-statistic for each factor (F_Method, F_Background, F_Interaction) using the mean squares:
#
# - $F_{Method} = \frac{MS_{Method}}{MSE}$
# - $F_{Background} = \frac{MS_{Background}}{MSE}$
# - $F_{Interaction} = \frac{MS_{Interaction}}{MSE}$
#
# MSE is the mean square of error (residuals).
#
# **Step 8: P-Value**
#
# Calculate the p-values associated with the F-statistics using the F-distribution.
#
# **Step 9: Hypothesis Testing**
#
# Conduct hypothesis tests for each factor and interaction:
#
# - For Teaching Method (F-Test for Method): Compare $F_{Method}$ to the critical value or calculate the p-value.
# - For Student Background (F-Test for Background): Compare $F_{Background}$ to the critical value or calculate the p-value.
# - For the interaction (F-Test for Interaction): Compare $F_{Interaction}$ to the critical value or calculate the p-value.
#
# **Step 10: Interpretation**
#
# - If any of the F-tests (for Teaching Method, Student Background, or the interaction) are statistically significant (p < alpha), you reject the null hypothesis.
# - Determine the significance of the main effects and interaction effects.
#
# The specific critical values and p-value thresholds for significance depend on your chosen alpha level and the degrees of freedom. If any of the tests are significant, you can further investigate the nature of the effects using post hoc tests or pairwise comparisons.
